# %% [markdown]
# ### **Actividad Grupal - Análisis de datos**
#
# Diego Anibal Vazquez
#
# ---

# %% [markdown]
# # **Punto 1**
#
# Exploración y comprensión de los datos:
#
#
# *   Cargar Dataset y realizar EDA.
# *   Describir las características principales del dataset, incluyendo número de observaciones, número de variables y tipos de datos.
# * Identificar patrones generales y distribuciones.
# * Identificar errores, outliers, valores faltantes y su tipo (MCAR, MAR, MNAR).

# %% [markdown]
# importo bibliotecas

# %%
import sys
# !{sys.executable} -m pip install missingno
# Out:
# Requirement already satisfied: missingno in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: numpy in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from missingno) (2.2.5)
# Requirement already satisfied: matplotlib in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from missingno) (3.10.8)
# Requirement already satisfied: scipy in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from missingno) (1.15.3)
# Requirement already satisfied: seaborn in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (26.0)
# Requirement already satisfied: pillow>=8 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from seaborn->missingno) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from pandas>=1.2->seaborn->missingno) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from pandas>=1.2->seaborn->missingno) (2025.3)

# %%
import pandas as pd
import numpy as  np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import CategoricalDtype
import missingno as msno
from scipy import stats as st
from scipy.stats import describe
from sklearn.model_selection import train_test_split
from scipy.stats import chi2_contingency

# %% [markdown]
# levanto el dataset

# %%
# Ruta al CSV
file_path = 'datasets/NYPD_Complaint_Data_Current_(Year_To_Date)_20260504.zip'
# Lectura del CSV y creación del dataframe
df = pd.read_csv(file_path)

# %%
#Establece la opción para mostrar todas las columnas (si no muestra sólo 20)
pd.set_option('display.max_columns', None)
display(df.head(15))
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   322232997           60       BROOKLYN   03/01/2026     10:00:00
# 1   319667320           61       BROOKLYN   01/30/2026     14:00:00
# 2   319668752           47          BRONX   01/30/2026     22:25:00
# 3   322203999          122  STATEN ISLAND   03/21/2026     03:15:00
# 4   322235003          123  STATEN ISLAND   03/22/2026     20:30:00
# 5   322360334          123  STATEN ISLAND   03/25/2026     03:00:00
# 6   322705295          121  STATEN ISLAND   03/31/2026     19:50:00
# 7   322088066          121  STATEN ISLAND   03/19/2026     15:25:00
# 8   321529381          101         QUEENS   03/09/2026     10:40:00
# 9   318700273          120  STATEN ISLAND   01/10/2026     10:00:00
# 10  320987360          101         QUEENS   02/25/2026     23:00:00
# 11  318560142          121  STATEN ISLAND   01/08/2026     02:40:00
# 12  318870543          122  STATEN ISLAND   01/14/2026     11:50:00
# 13  321423946          122  STATEN ISLAND   03/06/2026     15:48:00
# 14  319883201           60       BROOKLYN   02/04/2026     11:28:00
#
#    CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 0    03/13/2026     00:00:00        COMPLETED     (null)          NaN
# 1    01/30/2026     14:05:00        COMPLETED     (null)          NaN
# 2    01/30/2026     22:30:00        COMPLETED     (null)          NaN
# 3    03/21/2026     03:20:00        COMPLETED     (null)          NaN
# 4    03/22/2026     20:50:00        COMPLETED     (null)          NaN
# 5    03/25/2026     03:20:00        COMPLETED     (null)          NaN
# 6    03/31/2026     20:00:00        COMPLETED     (null)          NaN
# 7    03/19/2026     16:05:00        COMPLETED     (null)          NaN
# 8    03/09/2026     10:43:00        COMPLETED     (null)          NaN
# 9    01/10/2026     15:34:00        COMPLETED     (null)          NaN
# 10   02/26/2026     07:00:00        COMPLETED     (null)          NaN
# 11   01/08/2026     02:50:00        ATTEMPTED     (null)          NaN
# 12   01/14/2026     11:56:00        COMPLETED     (null)       1291.0
# 13   03/06/2026     16:00:00        COMPLETED     (null)          NaN
# 14   02/04/2026     11:30:00        COMPLETED     (null)          NaN
#
#     JURISDICTION_CODE           JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0                   0     N.Y. POLICE DEPT    340  MISDEMEANOR
# 1                   0     N.Y. POLICE DEPT    344  MISDEMEANOR
# 2                   0     N.Y. POLICE DEPT    113       FELONY
# 3                   0     N.Y. POLICE DEPT    578    VIOLATION
# 4                   0     N.Y. POLICE DEPT    344  MISDEMEANOR
# 5                   0     N.Y. POLICE DEPT    348  MISDEMEANOR
# 6                   0     N.Y. POLICE DEPT    126       FELONY
# 7                   0     N.Y. POLICE DEPT    348  MISDEMEANOR
# 8                   0     N.Y. POLICE DEPT    341  MISDEMEANOR
# 9                   0     N.Y. POLICE DEPT    341  MISDEMEANOR
# 10                  0     N.Y. POLICE DEPT    341  MISDEMEANOR
# 11                  0     N.Y. POLICE DEPT    110       FELONY
# 12                  2  N.Y. HOUSING POLICE    235  MISDEMEANOR
# 13                  0     N.Y. POLICE DEPT    578    VIOLATION
# 14                  0     N.Y. POLICE DEPT    578    VIOLATION
#
#    LOC_OF_OCCUR_DESC                       OFNS_DESC PARKS_NM  \
# 0             INSIDE                          FRAUDS   (null)
# 1             INSIDE    ASSAULT 3 & RELATED OFFENSES   (null)
# 2             (null)                         FORGERY   (null)
# 3           FRONT OF                   HARRASSMENT 2   (null)
# 4             INSIDE    ASSAULT 3 & RELATED OFFENSES   (null)
# 5             (null)        VEHICLE AND TRAFFIC LAWS   (null)
# 6             INSIDE         MISCELLANEOUS PENAL LAW   (null)
# 7           FRONT OF        VEHICLE AND TRAFFIC LAWS   (null)
# 8           FRONT OF                   PETIT LARCENY   (null)
# 9             INSIDE                   PETIT LARCENY   (null)
# 10          FRONT OF                   PETIT LARCENY   (null)
# 11          FRONT OF  GRAND LARCENY OF MOTOR VEHICLE   (null)
# 12          FRONT OF                 DANGEROUS DRUGS   (null)
# 13            INSIDE                   HARRASSMENT 2   (null)
# 14            INSIDE                   HARRASSMENT 2   (null)
#
#                   PATROL_BORO  PD_CD                         PD_DESC  \
# 0     PATROL BORO BKLYN SOUTH  718.0  FRAUD,UNCLASSIFIED-MISDEMEANOR
# 1     PATROL BORO BKLYN SOUTH  101.0                       ASSAULT 3
# 2           PATROL BORO BRONX  725.0       FORGERY,M.V. REGISTRATION
# 3   PATROL BORO STATEN ISLAND  638.0           HARASSMENT,SUBD 3,4,5
# 4   PATROL BORO STATEN ISLAND  101.0                       ASSAULT 3
# 5   PATROL BORO STATEN ISLAND  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN
# 6   PATROL BORO STATEN ISLAND  198.0             CRIMINAL CONTEMPT 1
# 7   PATROL BORO STATEN ISLAND  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN
# 8    PATROL BORO QUEENS SOUTH  338.0  LARCENY,PETIT FROM BUILDING,UN
# 9   PATROL BORO STATEN ISLAND  307.0  LARCENY,PETIT BY DISHONEST EMP
# 10   PATROL BORO QUEENS SOUTH  349.0  LARCENY,PETIT OF LICENSE PLATE
# 11  PATROL BORO STATEN ISLAND  441.0           LARCENY,GRAND OF AUTO
# 12  PATROL BORO STATEN ISLAND  511.0  CONTROLLED SUBSTANCE, POSSESSI
# 13  PATROL BORO STATEN ISLAND  638.0           HARASSMENT,SUBD 3,4,5
# 14    PATROL BORO BKLYN SOUTH  638.0           HARASSMENT,SUBD 3,4,5
#
#                    PREM_TYP_DESC      RPT_DT STATION_NAME SUSP_AGE_GROUP  \
# 0                RESIDENCE-HOUSE  03/21/2026       (null)        UNKNOWN
# 1                  PUBLIC SCHOOL  01/30/2026       (null)            <18
# 2                         STREET  01/30/2026       (null)          25-44
# 3                RESIDENCE-HOUSE  03/21/2026       (null)        UNKNOWN
# 4                RESIDENCE-HOUSE  03/22/2026       (null)          25-44
# 5                         STREET  03/25/2026       (null)          45-64
# 6                RESIDENCE-HOUSE  03/31/2026       (null)          45-64
# 7                         STREET  03/19/2026       (null)          45-64
# 8         RESIDENCE - APT. HOUSE  03/09/2026       (null)          25-44
# 9                    CHAIN STORE  01/10/2026       (null)        UNKNOWN
# 10  PARKING LOT/GARAGE (PRIVATE)  02/26/2026       (null)        UNKNOWN
# 11                        STREET  01/08/2026       (null)        UNKNOWN
# 12    RESIDENCE - PUBLIC HOUSING  01/14/2026       (null)         (null)
# 13                 PUBLIC SCHOOL  03/06/2026       (null)        UNKNOWN
# 14        RESIDENCE - APT. HOUSE  02/04/2026       (null)          18-24
#
#          SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT VIC_AGE_GROUP  \
# 0          UNKNOWN        U               NaN         25-44
# 1            WHITE        M               NaN           <18
# 2            BLACK        F               NaN       UNKNOWN
# 3          UNKNOWN        U               NaN         45-64
# 4   WHITE HISPANIC        M               NaN         25-44
# 5            WHITE        M               NaN       UNKNOWN
# 6            WHITE        M               NaN         25-44
# 7            WHITE        M               NaN       UNKNOWN
# 8            BLACK        F               NaN         25-44
# 9   WHITE HISPANIC        M               NaN       UNKNOWN
# 10         UNKNOWN        U               NaN         25-44
# 11           BLACK        M               NaN         25-44
# 12          (null)   (null)               NaN       UNKNOWN
# 13           BLACK        F               NaN         25-44
# 14           BLACK        F               NaN         25-44
#
#                     VIC_RACE VIC_SEX  X_COORD_CD  Y_COORD_CD     Latitude  \
# 0                      WHITE       M      995229      149429    40,576826
# 1                      WHITE       M      998516      161667    40,610414
# 2                    UNKNOWN       E     1025119      268754   40,9042464
# 3                      WHITE       M      938726      139994     40,55082
# 4             WHITE HISPANIC       F      934395      143898    40,561512
# 5                    UNKNOWN       E      922746      139826  40,55025242
# 6                      WHITE       F      939956      161133    40,608848
# 7                    UNKNOWN       E      943977      153740    40,588575
# 8                      BLACK       M     1044590      156200    40,595214
# 9                    UNKNOWN       D      964832      164885    40,619236
# 10                     BLACK       F     1053765      158439    40,601291
# 11  ASIAN / PACIFIC ISLANDER       F      941373      163201    40,614532
# 12                   UNKNOWN       E      962283      156713      40,5968
# 13            WHITE HISPANIC       F      958923      159210    40,603645
# 14                     BLACK       F      984147      150277    40,579162
#
#        Longitude                      Lat_Lon  \
# 0     -73,960478      (40.576826, -73.960478)
# 1     -73,948619      (40.610414, -73.948619)
# 2   -73,85215489   (40.9042464, -73.85215489)
# 3     -74,163815       (40.55082, -74.163815)
# 4     -74,179427      (40.561512, -74.179427)
# 5   -74,22131435  (40.55025242, -74.22131435)
# 6     -74,159526      (40.608848, -74.159526)
# 7     -74,145002      (40.588575, -74.145002)
# 8     -73,782726      (40.595214, -73.782726)
# 9     -74,069944      (40.619236, -74.069944)
# 10    -73,749667      (40.601291, -73.749667)
# 11    -74,154436      (40.614532, -74.154436)
# 12    -74,079099        (40.5968, -74.079099)
# 13     -74,09121       (40.603645, -74.09121)
# 14    -74,000371      (40.579162, -74.000371)
#
#             New Georeferenced Column
# 0       POINT (-73.960478 40.576826)
# 1       POINT (-73.948619 40.610414)
# 2    POINT (-73.85215489 40.9042464)
# 3        POINT (-74.163815 40.55082)
# 4       POINT (-74.179427 40.561512)
# 5   POINT (-74.22131435 40.55025242)
# 6       POINT (-74.159526 40.608848)
# 7       POINT (-74.145002 40.588575)
# 8       POINT (-73.782726 40.595214)
# 9       POINT (-74.069944 40.619236)
# 10      POINT (-73.749667 40.601291)
# 11      POINT (-74.154436 40.614532)
# 12        POINT (-74.079099 40.5968)
# 13       POINT (-74.09121 40.603645)
# 14      POINT (-74.000371 40.579162)

# %% [markdown]
# Solo vamos a usar los casos del 2025 (lo pide el tp)

# %%
df = df[
    df['CMPLNT_FR_DT'].str.endswith('2025', na=False)
]
display(df.head(15))
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 69   318383739           60       BROOKLYN   01/01/2025     13:40:00
# 70   318305144          101         QUEENS   12/30/2025     10:34:00
# 95   318315162           63       BROOKLYN   12/31/2025     21:00:00
# 99   320247490           60       BROOKLYN   11/20/2025     20:00:00
# 108  318256135           60       BROOKLYN   12/28/2025     19:09:00
# 112  318691474           63       BROOKLYN   12/24/2025     11:30:00
# 122  318613754           61       BROOKLYN   12/28/2025     11:45:00
# 128  320451879           61       BROOKLYN   12/31/2025     15:00:00
# 129  319567455           68       BROOKLYN   12/05/2025     15:00:00
# 148  318283603           61       BROOKLYN   12/20/2025     20:00:00
# 153  319497345          123  STATEN ISLAND   10/11/2025     15:30:00
# 184  318537320          121  STATEN ISLAND   12/31/2025     21:00:00
# 204  318392446          122  STATEN ISLAND   12/23/2025     13:00:00
# 219  318874057          122  STATEN ISLAND   12/14/2025     03:00:00
# 234  321025215           68       BROOKLYN   11/01/2025     12:00:00
#
#     CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 69    01/01/2026     13:45:00        COMPLETED     (null)          NaN
# 70    12/30/2025     21:00:00        COMPLETED     (null)          NaN
# 95    12/31/2025     21:30:00        COMPLETED     (null)          NaN
# 99    11/20/2025     21:00:00        COMPLETED     (null)          NaN
# 108   12/28/2025     19:10:00        COMPLETED     (null)          NaN
# 112   12/24/2025     16:29:00        COMPLETED     (null)          NaN
# 122   12/28/2025     12:00:00        COMPLETED     (null)          NaN
# 128   02/08/2026     12:00:00        COMPLETED     (null)          NaN
# 129   01/05/2026     10:00:00        COMPLETED     (null)          NaN
# 148   12/21/2025     09:00:00        COMPLETED     (null)          NaN
# 153   12/20/2025     21:50:00        COMPLETED     (null)          NaN
# 184   12/31/2025     21:10:00        COMPLETED     (null)          NaN
# 204   12/23/2025     13:00:00        COMPLETED     (null)          NaN
# 219   12/14/2025     08:30:00        COMPLETED     (null)          NaN
# 234   02/23/2026     12:00:00        COMPLETED     (null)          NaN
#
#      JURISDICTION_CODE        JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 69                   0  N.Y. POLICE DEPT    578    VIOLATION
# 70                   0  N.Y. POLICE DEPT    341  MISDEMEANOR
# 95                   0  N.Y. POLICE DEPT    578    VIOLATION
# 99                   0  N.Y. POLICE DEPT    109       FELONY
# 108                  0  N.Y. POLICE DEPT    105       FELONY
# 112                  0  N.Y. POLICE DEPT    341  MISDEMEANOR
# 122                  0  N.Y. POLICE DEPT    355  MISDEMEANOR
# 128                  0  N.Y. POLICE DEPT    107       FELONY
# 129                  0  N.Y. POLICE DEPT    109       FELONY
# 148                  0  N.Y. POLICE DEPT    341  MISDEMEANOR
# 153                  0  N.Y. POLICE DEPT    109       FELONY
# 184                  0  N.Y. POLICE DEPT    341  MISDEMEANOR
# 204                  0  N.Y. POLICE DEPT    340  MISDEMEANOR
# 219                  0  N.Y. POLICE DEPT    361  MISDEMEANOR
# 234                  0  N.Y. POLICE DEPT    340  MISDEMEANOR
#
#     LOC_OF_OCCUR_DESC                      OFNS_DESC PARKS_NM  \
# 69             INSIDE                  HARRASSMENT 2   (null)
# 70             INSIDE                  PETIT LARCENY   (null)
# 95           FRONT OF                  HARRASSMENT 2   (null)
# 99             INSIDE                  GRAND LARCENY   (null)
# 108            INSIDE                        ROBBERY   (null)
# 112            (null)                  PETIT LARCENY   (null)
# 122            (null)    OFFENSES AGAINST THE PERSON   (null)
# 128            INSIDE                       BURGLARY   (null)
# 129            INSIDE                  GRAND LARCENY   (null)
# 148           REAR OF                  PETIT LARCENY   (null)
# 153            INSIDE                  GRAND LARCENY   (null)
# 184            INSIDE                  PETIT LARCENY   (null)
# 204            INSIDE                         FRAUDS   (null)
# 219            INSIDE  OFF. AGNST PUB ORD SENSBLTY &   (null)
# 234            INSIDE                         FRAUDS   (null)
#
#                    PATROL_BORO  PD_CD  \
# 69     PATROL BORO BKLYN SOUTH  638.0
# 70    PATROL BORO QUEENS SOUTH  352.0
# 95     PATROL BORO BKLYN SOUTH  638.0
# 99     PATROL BORO BKLYN SOUTH  412.0
# 108    PATROL BORO BKLYN SOUTH  399.0
# 112    PATROL BORO BKLYN SOUTH  353.0
# 122    PATROL BORO BKLYN SOUTH  115.0
# 128    PATROL BORO BKLYN SOUTH  224.0
# 129    PATROL BORO BKLYN SOUTH  402.0
# 148    PATROL BORO BKLYN SOUTH  343.0
# 153  PATROL BORO STATEN ISLAND  437.0
# 184  PATROL BORO STATEN ISLAND  338.0
# 204  PATROL BORO STATEN ISLAND  718.0
# 219  PATROL BORO STATEN ISLAND  639.0
# 234    PATROL BORO BKLYN SOUTH  718.0
#
#                                                PD_DESC  \
# 69                               HARASSMENT,SUBD 3,4,5
# 70   LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAG...
# 95                               HARASSMENT,SUBD 3,4,5
# 99            LARCENY,GRAND FROM RESIDENCE, UNATTENDED
# 108                    ROBBERY,COMMERCIAL UNCLASSIFIED
# 112  LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAG...
# 122                            RECKLESS ENDANGERMENT 2
# 128                     BURGLARY,RESIDENCE,UNKNOWN TIM
# 129  LARCENY,GRAND BY FALSE PROMISE-NOT IN PERSON C...
# 148                           LARCENY,PETIT OF BICYCLE
# 153   LARCENY,GRAND BY FALSE PROMISE-IN PERSON CONTACT
# 184                     LARCENY,PETIT FROM BUILDING,UN
# 204                     FRAUD,UNCLASSIFIED-MISDEMEANOR
# 219                            AGGRAVATED HARASSMENT 2
# 234                     FRAUD,UNCLASSIFIED-MISDEMEANOR
#
#               PREM_TYP_DESC      RPT_DT STATION_NAME SUSP_AGE_GROUP  \
# 69           GROCERY/BODEGA  01/01/2026       (null)        UNKNOWN
# 70   RESIDENCE - APT. HOUSE  01/03/2026       (null)        UNKNOWN
# 95          RESIDENCE-HOUSE  01/01/2026       (null)        UNKNOWN
# 99   RESIDENCE - APT. HOUSE  02/11/2026       (null)          45-64
# 108               FAST FOOD  01/02/2026       (null)        UNKNOWN
# 112         RESIDENCE-HOUSE  01/11/2026       (null)         (null)
# 122                  STREET  01/06/2026       (null)        UNKNOWN
# 128  RESIDENCE - APT. HOUSE  02/15/2026       (null)         (null)
# 129                   OTHER  01/28/2026       (null)          25-44
# 148         RESIDENCE-HOUSE  01/02/2026       (null)         (null)
# 153         RESIDENCE-HOUSE  01/27/2026       (null)          25-44
# 184  RESIDENCE - APT. HOUSE  01/07/2026       (null)        UNKNOWN
# 204         RESIDENCE-HOUSE  01/05/2026       (null)         (null)
# 219         RESIDENCE-HOUSE  01/14/2026       (null)        UNKNOWN
# 234         RESIDENCE-HOUSE  02/27/2026       (null)        UNKNOWN
#
#                           SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT VIC_AGE_GROUP  \
# 69                            BLACK        M               NaN         25-44
# 70                          UNKNOWN        U               NaN         25-44
# 95                          UNKNOWN        U               NaN         25-44
# 99                            BLACK        F               NaN         45-64
# 108                           BLACK        M               NaN         18-24
# 112                          (null)   (null)               NaN         25-44
# 122                         UNKNOWN        M               NaN         45-64
# 128                          (null)   (null)               NaN         45-64
# 129                           WHITE        M               NaN       UNKNOWN
# 148                          (null)   (null)               NaN         25-44
# 153                  BLACK HISPANIC        M               NaN         45-64
# 184  AMERICAN INDIAN/ALASKAN NATIVE        F               NaN         25-44
# 204                          (null)   (null)               NaN         45-64
# 219                         UNKNOWN        U               NaN         25-44
# 234                         UNKNOWN        U               NaN         25-44
#
#                      VIC_RACE VIC_SEX  X_COORD_CD  Y_COORD_CD     Latitude  \
# 69   ASIAN / PACIFIC ISLANDER       M      989419      149229    40,576284
# 70                      BLACK       M     1051811      156239     40,59527
# 95                      BLACK       F     1007120      166200    40,622837
# 99                      BLACK       M      988814      149158    40,576087
# 108  ASIAN / PACIFIC ISLANDER       M      985092      148865    40,575285
# 112                     WHITE       M     1001637      164620    40,618513
# 122                     WHITE       M      999404      157426  40,59876127
# 128                     WHITE       F      997311      160637    40,607587
# 129                   UNKNOWN       D      976198      164520    40,618253
# 148  ASIAN / PACIFIC ISLANDER       M      995821      154908    40,591865
# 153  ASIAN / PACIFIC ISLANDER       M      938130      134459    40,535624
# 184                     WHITE       M      938084      153602    40,588167
# 204                     WHITE       M      949586      144770    40,563977
# 219            WHITE HISPANIC       F      955383      150160    40,578793
# 234            WHITE HISPANIC       F      975529      164781    40,618968
#
#         Longitude                      Lat_Lon  \
# 69     -73,981392      (40.576284, -73.981392)
# 70     -73,756726       (40.59527, -73.756726)
# 95     -73,917614      (40.622837, -73.917614)
# 99     -73,983569      (40.576087, -73.983569)
# 108    -73,996969      (40.575285, -73.996969)
# 112    -73,937371      (40.618513, -73.937371)
# 122  -73,94543068  (40.59876127, -73.94543068)
# 128    -73,952959      (40.607587, -73.952959)
# 129    -74,029003      (40.618253, -74.029003)
# 148    -73,958338      (40.591865, -73.958338)
# 153    -74,165919      (40.535624, -74.165919)
# 184    -74,166218      (40.588167, -74.166218)
# 204    -74,124759      (40.563977, -74.124759)
# 219    -74,103917      (40.578793, -74.103917)
# 234    -74,031412      (40.618968, -74.031412)
#
#              New Georeferenced Column
# 69       POINT (-73.981392 40.576284)
# 70        POINT (-73.756726 40.59527)
# 95       POINT (-73.917614 40.622837)
# 99       POINT (-73.983569 40.576087)
# 108      POINT (-73.996969 40.575285)
# 112      POINT (-73.937371 40.618513)
# 122  POINT (-73.94543068 40.59876127)
# 128      POINT (-73.952959 40.607587)
# 129      POINT (-74.029003 40.618253)
# 148      POINT (-73.958338 40.591865)
# 153      POINT (-74.165919 40.535624)
# 184      POINT (-74.166218 40.588167)
# 204      POINT (-74.124759 40.563977)
# 219      POINT (-74.103917 40.578793)
# 234      POINT (-74.031412 40.618968)

# %% [markdown]
# Cantidad de filas y columnas

# %%
df.shape
# Out:
# (5939, 36)

# %% [markdown]
# Pantallazo de columnas, cuenta de no nulls y tipos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 69 to 133090
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CMPLNT_NUM                5939 non-null   object
#  1   ADDR_PCT_CD               5939 non-null   int64
#  2   BORO_NM                   5939 non-null   object
#  3   CMPLNT_FR_DT              5939 non-null   object
#  4   CMPLNT_FR_TM              5939 non-null   object
#  5   CMPLNT_TO_DT              5579 non-null   object
#  6   CMPLNT_TO_TM              5939 non-null   object
#  7   CRM_ATPT_CPTD_CD          5939 non-null   object
#  8   HADEVELOPT                5939 non-null   object
#  9   HOUSING_PSA               323 non-null    float64
#  10  JURISDICTION_CODE         5939 non-null   int64
#  11  JURIS_DESC                5939 non-null   object
#  12  KY_CD                     5939 non-null   int64
#  13  LAW_CAT_CD                5939 non-null   object
#  14  LOC_OF_OCCUR_DESC         5939 non-null   object
#  15  OFNS_DESC                 5939 non-null   object
#  16  PARKS_NM                  5939 non-null   object
#  17  PATROL_BORO               5939 non-null   object
#  18  PD_CD                     5932 non-null   float64
#  19  PD_DESC                   5939 non-null   object
#  20  PREM_TYP_DESC             5939 non-null   object
#  21  RPT_DT                    5939 non-null   object
#  22  STATION_NAME              5939 non-null   object
#  23  SUSP_AGE_GROUP            5939 non-null   object
#  24  SUSP_RACE                 5939 non-null   object
#  25  SUSP_SEX                  5939 non-null   object
#  26  TRANSIT_DISTRICT          90 non-null     float64
#  27  VIC_AGE_GROUP             5939 non-null   object
#  28  VIC_RACE                  5939 non-null   object
#  29  VIC_SEX                   5939 non-null   object
#  30  X_COORD_CD                5939 non-null   int64
#  31  Y_COORD_CD                5939 non-null   int64
#  32  Latitude                  5939 non-null   object
#  33  Longitude                 5939 non-null   object
#  34  Lat_Lon                   5939 non-null   object
#  35  New Georeferenced Column  5939 non-null   object
# dtypes: float64(3), int64(5), object(28)
# memory usage: 1.7+ MB

# %%
delito_cat_nom = [
    'BORO_NM',
    'CRM_ATPT_CPTD_CD',
    'HADEVELOPT',
    'JURIS_DESC',
    'LAW_CAT_CD',
    'OFNS_DESC',
    'PATROL_BORO',
    'KY_CD',
    'PD_CD',
    'PD_DESC',
    'PREM_TYP_DESC',
    'SUSP_RACE',
    'SUSP_SEX',
    'VIC_RACE',
    'VIC_SEX',
    'ADDR_PCT_CD',
    'HOUSING_PSA',
    'JURISDICTION_CODE',
    'LOC_OF_OCCUR_DESC',
    'PARKS_NM',
    'STATION_NAME',
    'SUSP_AGE_GROUP',
    'TRANSIT_DISTRICT',
    'VIC_AGE_GROUP'
]#delito_cat_num= ['ADDR_PCT_CD', 'ADDR_PCT_CD','sibsp', 'parch']
dtype_map ={col: 'category' for col in delito_cat_nom}

df = df.astype(dtype_map)
# Aplicamos el mapping al DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 69 to 133090
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CMPLNT_NUM                5939 non-null   object
#  1   ADDR_PCT_CD               5939 non-null   category
#  2   BORO_NM                   5939 non-null   category
#  3   CMPLNT_FR_DT              5939 non-null   object
#  4   CMPLNT_FR_TM              5939 non-null   object
#  5   CMPLNT_TO_DT              5579 non-null   object
#  6   CMPLNT_TO_TM              5939 non-null   object
#  7   CRM_ATPT_CPTD_CD          5939 non-null   category
#  8   HADEVELOPT                5939 non-null   category
#  9   HOUSING_PSA               323 non-null    category
#  10  JURISDICTION_CODE         5939 non-null   category
#  11  JURIS_DESC                5939 non-null   category
#  12  KY_CD                     5939 non-null   category
#  13  LAW_CAT_CD                5939 non-null   category
#  14  LOC_OF_OCCUR_DESC         5939 non-null   category
#  15  OFNS_DESC                 5939 non-null   category
#  16  PARKS_NM                  5939 non-null   category
#  17  PATROL_BORO               5939 non-null   category
#  18  PD_CD                     5932 non-null   category
#  19  PD_DESC                   5939 non-null   category
#  20  PREM_TYP_DESC             5939 non-null   category
#  21  RPT_DT                    5939 non-null   object
#  22  STATION_NAME              5939 non-null   category
#  23  SUSP_AGE_GROUP            5939 non-null   category
#  24  SUSP_RACE                 5939 non-null   category
#  25  SUSP_SEX                  5939 non-null   category
#  26  TRANSIT_DISTRICT          90 non-null     category
#  27  VIC_AGE_GROUP             5939 non-null   category
#  28  VIC_RACE                  5939 non-null   category
#  29  VIC_SEX                   5939 non-null   category
#  30  X_COORD_CD                5939 non-null   int64
#  31  Y_COORD_CD                5939 non-null   int64
#  32  Latitude                  5939 non-null   object
#  33  Longitude                 5939 non-null   object
#  34  Lat_Lon                   5939 non-null   object
#  35  New Georeferenced Column  5939 non-null   object
# dtypes: category(24), int64(2), object(10)
# memory usage: 791.9+ KB

# %% [markdown]
# de esta información y de la fuente podemos determinar:
#
# N° | Column Name              | API Field | Data Type           | Description
# ---|--------------------------|-----------|---------------------|------------
# 1  | CMPLNT_NUM              | cmplnt_num| Text                | Identificador único de la denuncia
# 2  | ADDR_PCT_CD             | addr_pct_cd| Numeric             | Precinto donde ocurrió el incidente
# 3  | BORO_NM                 | boro_nm   | Text                | Borough donde ocurrió el incidente
# 4  | CMPLNT_FR_DT            | cmplnt_fr_dt| Date                | Fecha de inicio del incidente
# 5  | CMPLNT_FR_TM            | cmplnt_fr_tm| Time (Text)         | Hora de inicio del incidente
# 6  | CMPLNT_TO_DT            | cmplnt_to_dt| Date                | Fecha de fin del incidente
# 7  | CMPLNT_TO_TM            | cmplnt_to_tm| Time (Text)         | Hora de fin del incidente
# 8  | CRM_ATPT_CPTD_CD        | crm_atpt_cptd_cd| Text                | Indica si el delito fue consumado o intentado
# 9  | HADEVELOPT              | hadevelopt| Text                | Complejo habitacional (si aplica)
# 10 | HOUSING_PSA             | housing_psa| Numeric             | Código de área de vivienda
# 11 | JURISDICTION_CODE       | jurisdiction_code| Numeric             | Código de jurisdicción
# 12 | JURIS_DESC              | juris_desc| Text                | Descripción de la jurisdicción
# 13 | KY_CD                   | ky_cd     | Numeric             | Código general del delito
# 14 | LAW_CAT_CD              | law_cat_cd| Text                | Nivel del delito (felony/misdemeanor/violation)
# 15 | LOC_OF_OCCUR_DESC       | loc_of_occur_desc| Text                | Ubicación relativa del hecho
# 16 | OFNS_DESC               | ofns_desc | Text                | Descripción del delito
# 17 | PARKS_NM                | parks_nm  | Text                | Nombre del parque (si aplica)
# 18 | PATROL_BORO             | patrol_boro| Text                | Zona de patrullaje
# 19 | PD_CD                   | pd_cd     | Numeric             | Código interno del delito
# 20 | PD_DESC                 | pd_desc   | Text                | Descripción detallada del delito
# 21 | PREM_TYP_DESC           | prem_typ_desc| Text                | Tipo de establecimiento
# 22 | RPT_DT                  | rpt_dt    | Date                | Fecha de reporte
# 23 | STATION_NAME            | station_name| Text                | Estación de tránsito
# 24 | SUSP_AGE_GROUP          | susp_age_group| Text                | Edad del sospechoso
# 25 | SUSP_RACE               | susp_race | Text                | Raza del sospechoso
# 26 | SUSP_SEX                | susp_sex  | Text                | Sexo del sospechoso
# 27 | TRANSIT_DISTRICT        | transit_district| Numeric             | Distrito de tránsito
# 28 | VIC_AGE_GROUP           | vic_age_group| Text                | Edad de la víctima
# 29 | VIC_RACE                | vic_race  | Text                | Raza de la víctima
# 30 | VIC_SEX                 | vic_sex   | Text                | Sexo de la víctima
# 31 | X_COORD_CD              | x_coord_cd| Numeric             | Coordenada X (sistema estatal)
# 32 | Y_COORD_CD              | y_coord_cd| Numeric             | Coordenada Y (sistema estatal)
# 33 | Latitude                | latitude  | Numeric (latitude)  | Latitud geográfica
# 34 | Longitude               | longitude | Numeric (longitude) | Longitud geográfica
# 35 | Lat_Lon                 | lat_lon   | Point               | Coordenadas combinadas
# 36 | New Georeferenced Column| new_georeferenced_column| Point               | Punto georreferenciado

# %% [markdown]
# Identifico error en nulles y hago replace porque hay atributos donde el null esta expresado de forma distinta, asi que unifico y homogeneizar distintas representaciones de valores faltantes

# %%
df = df.replace([
    'NULL', 'null', '(null)', 'NaN', 'N/A', 'na', 'NA', '', ' '
], np.nan)

# también limpiar strings con espacios
df = df.replace(r'^\s*$', np.nan, regex=True)
# Out:
# /tmp/ipykernel_179411/836765493.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df = df.replace([

# %% [markdown]
# reviso de vuelta info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 69 to 133090
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CMPLNT_NUM                5939 non-null   object
#  1   ADDR_PCT_CD               5939 non-null   category
#  2   BORO_NM                   5884 non-null   category
#  3   CMPLNT_FR_DT              5939 non-null   object
#  4   CMPLNT_FR_TM              5939 non-null   object
#  5   CMPLNT_TO_DT              5579 non-null   object
#  6   CMPLNT_TO_TM              5575 non-null   object
#  7   CRM_ATPT_CPTD_CD          5939 non-null   category
#  8   HADEVELOPT                16 non-null     category
#  9   HOUSING_PSA               323 non-null    category
#  10  JURISDICTION_CODE         5939 non-null   category
#  11  JURIS_DESC                5939 non-null   category
#  12  KY_CD                     5939 non-null   category
#  13  LAW_CAT_CD                5939 non-null   category
#  14  LOC_OF_OCCUR_DESC         5306 non-null   category
#  15  OFNS_DESC                 5939 non-null   category
#  16  PARKS_NM                  24 non-null     category
#  17  PATROL_BORO               5939 non-null   category
#  18  PD_CD                     5932 non-null   category
#  19  PD_DESC                   5932 non-null   category
#  20  PREM_TYP_DESC             5874 non-null   category
#  21  RPT_DT                    5939 non-null   object
#  22  STATION_NAME              90 non-null     category
#  23  SUSP_AGE_GROUP            4799 non-null   category
#  24  SUSP_RACE                 4799 non-null   category
#  25  SUSP_SEX                  4799 non-null   category
#  26  TRANSIT_DISTRICT          90 non-null     category
#  27  VIC_AGE_GROUP             5939 non-null   category
#  28  VIC_RACE                  5928 non-null   category
#  29  VIC_SEX                   5939 non-null   category
#  30  X_COORD_CD                5939 non-null   int64
#  31  Y_COORD_CD                5939 non-null   int64
#  32  Latitude                  5939 non-null   object
#  33  Longitude                 5939 non-null   object
#  34  Lat_Lon                   5939 non-null   object
#  35  New Georeferenced Column  5939 non-null   object
# dtypes: category(24), int64(2), object(10)
# memory usage: 791.6+ KB

# %% [markdown]
# Tipos de variables del dataset y descripción
#
# | Columna | Tipo de dato | Qué representa |
# |----------|-------------|----------------|
# | CMPLNT_NUM | Identificador (object) | ID único del incidente |
# | ADDR_PCT_CD | Categórica | Precinto policial del incidente |
# | BORO_NM | Categórica | Borough donde ocurrió el hecho |
# | CMPLNT_FR_DT | Temporal (object) | Fecha de inicio del incidente |
# | CMPLNT_FR_TM | Temporal (object) | Hora de inicio del incidente |
# | CMPLNT_TO_DT | Temporal (object) | Fecha de fin del incidente |
# | CMPLNT_TO_TM | Temporal (object) | Hora de fin del incidente |
# | CRM_ATPT_CPTD_CD | Categórica | Indica si el delito fue consumado o intentado |
# | HADEVELOPT | Categórica  | Desarrollo habitacional donde ocurrió el hecho |
# | HOUSING_PSA | Categórica | Área de seguridad de vivienda pública |
# | JURISDICTION_CODE | Categórica numérica | Código de jurisdicción del hecho |
# | JURIS_DESC | Categórica | Descripción de la jurisdicción (policía, tránsito, etc.) |
# | KY_CD | Categórica numérica | Código de categoría del delito |
# | LAW_CAT_CD | Categórica | Nivel legal del delito (felony, misdemeanor, violation) |
# | LOC_OF_OCCUR_DESC | Categórica | Ubicación específica del hecho |
# | OFNS_DESC | Categórica | Descripción del tipo de delito |
# | PARKS_NM | Categórica | Nombre del parque donde ocurrió el hecho |
# | PATROL_BORO | Categórica | División de patrullaje policial |
# | PD_CD | Categórica numérica | Código del delito (Police Department Code) |
# | PD_DESC | Categórica | Descripción del código del delito |
# | PREM_TYP_DESC | Categórica | Tipo de establecimiento donde ocurrió el hecho |
# | RPT_DT | Temporal (object) | Fecha de reporte del incidente |
# | STATION_NAME | Categórica (contextual) | Estación de transporte asociada al hecho |
# | SUSP_AGE_GROUP | Categórica | Grupo etario del sospechoso |
# | SUSP_RACE | Categórica | Raza del sospechoso |
# | SUSP_SEX | Categórica | Sexo del sospechoso |
# | TRANSIT_DISTRICT | Categórica  | Distrito de transporte asociado al hecho |
# | VIC_AGE_GROUP | Categórica | Grupo etario de la víctima |
# | VIC_RACE | Categórica | Raza de la víctima |
# | VIC_SEX | Categórica | Sexo de la víctima |
# | X_COORD_CD | Numérica | Coordenada X del hecho |
# | Y_COORD_CD | Numérica | Coordenada Y del hecho |
# | Latitude | Numérica (object) | Latitud geográfica |
# | Longitude | Numérica (object) | Longitud geográfica |
# | Lat_Lon | Geográfica (object) | Coordenada combinada |
# | New Georeferenced Column | Geográfica (object) | Geolocalización en formato estructurado |

# %% [markdown]
# Verifico si hay valores dups

# %%
print("Cantidad de datos duplicados:", df.duplicated().sum())
# Out:
# Cantidad de datos duplicados: 0

# %% [markdown]
# Funcion para ver faltantes

# %%
def valores_faltante_tabla(df):
        # Total valores falantes
        mis_val = df.isnull().sum()

        # Percentaje de valores faltantes
        mis_val_percent = 100 * df.isnull().sum() / len(df)

        #
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

        # renombramos las columnas
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Valores faltantes ', 1 : '% de Total de valores'})

        # Ordenar la tabla por porcentaje de faltantes descendentes
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% de Total de valores', ascending=False).round(1)

        # Imprimimos un resumen
        print ("el dataframe tiene " + str(df.shape[1]) + " columnas.\n"
            " y hay " + str(mis_val_table_ren_columns.shape[0]) +
              " columnas con valores faltantes.")

        # devolvemos la informacion
        return mis_val_table_ren_columns

# %% [markdown]
# Listo los porcentajes de faltantes por atributo

# %%
valores_faltante_tabla(df)
# Out:
# el dataframe tiene 36 columnas.
#  y hay 16 columnas con valores faltantes.
#                    Valores faltantes   % de Total de valores
# HADEVELOPT                       5923                   99.7
# PARKS_NM                         5915                   99.6
# TRANSIT_DISTRICT                 5849                   98.5
# STATION_NAME                     5849                   98.5
# HOUSING_PSA                      5616                   94.6
# SUSP_RACE                        1140                   19.2
# SUSP_AGE_GROUP                   1140                   19.2
# SUSP_SEX                         1140                   19.2
# LOC_OF_OCCUR_DESC                 633                   10.7
# CMPLNT_TO_TM                      364                    6.1
# CMPLNT_TO_DT                      360                    6.1
# PREM_TYP_DESC                      65                    1.1
# BORO_NM                            55                    0.9
# VIC_RACE                           11                    0.2
# PD_CD                               7                    0.1
# PD_DESC                             7                    0.1

# %%
# Matriz de valores faltantes
msno.matrix(df, figsize=(20,8))
# Out:
# <Axes: >

# %% [markdown]
# Aca podemos ver que HADEVELOPT, PARKS_NM, TRANSIT_DISTRICT, STATION_NAME, HOUSING_PSA	son los que mas portentaje de nulos, se puede considerar eliminar estas columnas, falta hacer la clasificacion de los tipos de nulos.

# %%
msno.heatmap(df, fontsize=15, figsize=(15,8))
plt.title("Correlación de datos nulos", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlación de datos nulos')

# %% [markdown]
# La correlación entre los valores nulos de las distintas variables con el objetivo de identificar patrones de ausencia conjunta de información. La mayoría de las correlaciones observadas fueron bajas (entre -0.3 y 0.3), lo que dice que los datos faltantes se distribuyen de manera relativamente independiente entre las variables.
# Se identificaron algunos casos de correlación muy alta entre los faltantes. Las variables PD_CD y PD_DESC presentan una correlación cercana a 1.  También se observaron correlaciones prácticamente perfectas entre los faltantes de SUSP_AGE_GROUP, SUSP_RACE y SUSP_SEX, lo que indica que la información del sospechoso suele estar disponible o ausente de forma conjunta. Un patrón similar se observa entre SUSP_AGE_GROUP y TRANSIT_DISTRICT.
# Algunas variables presentan correlaciones negativas moderadas, como LOC_OF_OCCUR_DESC con STATION_NAME y TRANSIT_DISTRICT (≈ -0.3), lo que indica que la ausencia de información en una variable tiende a coincidir con la presencia de información en la otra.

# %% [markdown]
# dendrograma de patrones de valores faltantes

# %%
msno.dendrogram(df, figsize=(15,8))
plt.title('Dendrograma de faltantes', fontsize=20)
plt.show()

# %% [markdown]
# Analisis:
# grupo 1: grupo de variables prácticamente sin faltantes
#
# A la izquierda aparece un gran conjunto:
#
# PD_DESC
# PD_CD
# ADDR_PCT_CD
# CMPLNT_FR_DT
# CMPLNT_FR_TM
# CMPLNT_TO_DT
# JURISDICTION_CODE
# KY_CD
# LAW_CAT_CD
# OFNS_DESC
# PATROL_BORO
# RPT_DT
# VIC_AGE_GROUP
# VIC_SEX
# X_COORD_CD
# Y_COORD_CD
# Latitude
# Longitude
# Lat_Lon
# New Georeferenced Column
#
# entonces,
#
# Interpretación:
#
# Constituyen el bloque principal del dendrograma.
# Presentan muy pocos valores faltantes o patrones de ausencia similares.
# Los registros donde faltan datos en estas variables tienden a coincidir.
# Desde el punto de vista de calidad de datos, corresponden a las variables más completas y consistentes del conjunto de datos.
# Las variables geográficas (Latitude, Longitude, X_COORD_CD, Y_COORD_CD, Lat_Lon) muestran además una fuerte similitud entre sí, lo que es esperable dado que representan distintas formas de registrar la ubicación del incidente.
#
# grupo 2:
# BORO_NM
# PREM_TYP_DESC
# CMPLNT_TO_TM
# LOC_OF_OCCUR_DESC
#
# Presentan un patrón de faltantes diferente al bloque principal.
# La ausencia de información en estas variables suele producirse conjuntamente.
# Esto sugiere que determinados registros carecen simultáneamente de información contextual sobre el lugar o las características del hecho.
# Constituyen un mecanismo de faltantes diferenciado respecto de las variables principales.
#
# Grupo 3:
# SUSP_RACE
# SUSP_AGE_GROUP
# SUSP_SEX
# Interpretación:
#
# Forman uno de los grupos más claramente definidos del dendrograma.
# Cuando falta información de una de estas variables, normalmente faltan también las demás.
# Esto sugiere que la ausencia de información del sospechoso responde a una causa común, posiblemente vinculada a incidentes en los que el sospechoso no fue identificado o no se registraron sus características.
#
# Grupo 4:
# PARKS_NM
# HADEVELOPT
# TRANSIT_DISTRICT
# STATION_NAME
# HOUSING_PSA
#
# Constituyen el grupo más diferenciado del dendrograma.
# Presentan un patrón de faltantes muy distinto al resto de las variables.
# Probablemente se debe a que sólo son aplicables en contextos específicos (parques, estaciones, transporte público o complejos habitacionales).
# Por lo tanto, permanecen vacías en la mayoría de los registros y sólo se completan cuando el incidente ocurre en dichos ámbitos.

# %% [markdown]
# **Clasificacion de nulos**

# %% [markdown]
# **para recordar:**
#
# MCAR: la falta del dato es aleatoria y no depende de ninguna variable.
#
# MAR: la falta del dato depende de otras variables observadas.
#
# MNAR: la falta del dato depende del dato en sí mismo.
#
# Estructural: no es realmente un faltante, sino un dato que no existe.
#
# Si el porcentaje de nulos es parecido en todos los grupos → podría ser MCAR.
#
# Si cambia mucho entre grupos → probablemente MAR.
#
# Si descubrís que la variable solo aplica a ciertos registros → Estructural.

# %% [markdown]
# Voy a dividir mis varibles por grupo x cantidad de nulos:

# %% [markdown]
# 1.   Con la mayor cantidad de nulos:
#
#
# | Variable         | % nulos |
# | ---------------- | ------- |
# | HADEVELOPT       | 99.7    |
# | PARKS_NM         | 99.6    |
# | TRANSIT_DISTRICT | 98.5    |
# | STATION_NAME     | 98.5    |
# | HOUSING_PSA      | 94.6    |

# %% [markdown]
# STATION_NAME ¿Todos los delitos ocurren en una estación?
# No, posiblemente sea estructural

# %%
print(df['STATION_NAME'].value_counts(dropna=False).head(20))
# Out:
# STATION_NAME
# NaN                               5849
# 50 STREET                            8
# ROOSEVELT AVE.-JACKSON HEIGHTS       5
# 49 STREET                            5
# WYCKOFF AVENUE                       4
# FORDHAM ROAD                         4
# 170 STREET                           4
# 21 ST.-QUEENSBRIDGE                  3
# 23 STREET                            3
# EAST 180 STREET                      2
# BROADWAY-EAST NEW YORK               2
# W. 4 STREET                          2
# 96TH STREET                          2
# 42 STREET                            2
# 42 ST.-TIMES SQUARE                  2
# 125 STREET                           2
# 47-50 STS./ROCKEFELLER CTR.          1
# 1 AVENUE                             1
# 111 STREET                           1
# 14 STREET                            1
# Name: count, dtype: int64

# %% [markdown]
# Son estaciones, se confirma que es estructural, ya que los delitos no se dan siempre en estaciones

# %% [markdown]
# HADEVELOPT ¿Todos los delitos ocurren en desarrollos habitacionales?
# No, posiblemente sea estructural

# %%
print(df['HADEVELOPT'].value_counts(dropna=False).head(20))
# Out:
# HADEVELOPT
# NaN                                5923
# INGERSOLL                             2
# RIIS                                  2
# WOODSIDE                              2
# GLENWOOD                              1
# CAMPOS PLAZA I                        1
# MARKHAM GARDENS                       1
# LOWER EAST SIDE REHAB (GROUP 5)       1
# GRANT                                 1
# NOSTRAND                              1
# SMITH                                 1
# RIIS II                               1
# WILLIAMSBURG                          1
# WHITMAN                               1
# Name: count, dtype: int64

# %% [markdown]
# Estructural, los delitos no se dan en desarrollos habitacionales.

# %% [markdown]
# PARKS_NM  ¿Todos los delitos ocurren en parques?
# No, posiblemente sea estructural

# %%
print(df['PARKS_NM'].value_counts(dropna=False).head(20))
# Out:
# PARKS_NM
# NaN                              5915
# SARA D. ROOSEVELT PARK              5
# CENTRAL PARK                        2
# BROOKLYN BRIDGE PARK                1
# CLAREMONT PARK                      1
# CHARLTON GARDEN                     1
# CLOVE LAKES PARK                    1
# FLUSHING MEADOWS CORONA PARK        1
# HAWKINS PARK                        1
# HUDSON RIVER PARK                   1
# GREELEY SQUARE PARK                 1
# GREENBELT NATIVE PLANT CENTER       1
# MILL POND PARK                      1
# LEIF ERICSON PARK                   1
# SOUNDVIEW PARK                      1
# QUEENSBRIDGE PARK                   1
# ST. MARY'S PARK BRONX               1
# STARLIGHT PARK                      1
# THOMAS JEFFERSON PARK               1
# UNION SQUARE PARK                   1
# Name: count, dtype: int64

# %% [markdown]
# Se confirma es estructural.

# %% [markdown]
# HOUSING_PSA los delitos ocurren en viviendas publicas?
# No, posiblemente sea estructural.

# %%
print(df['HOUSING_PSA'].value_counts(dropna=False).head(20))
# Out:
# HOUSING_PSA
# NaN         5616
#  73252.0       8
#  339.0         7
#  887.0         7
#  638.0         6
#  664.0         6
#  1251.0        6
#  1269.0        6
#  463.0         5
#  227.0         5
#  590.0         5
#  720.0         5
#  1193.0        5
#  632.0         5
#  672.0         5
#  619.0         4
#  811.0         4
#  845.0         4
#  352.0         4
#  245.0         4
# Name: count, dtype: int64

# %% [markdown]
# Aca esta mas dificil  porque no se que son esos números pero suena estructural.

# %% [markdown]
# TRANSIT_DISTRICT ¿Todos los delitos ocurren en transporte?
# Sospecho que sea estructural

# %%
print(df['TRANSIT_DISTRICT'].value_counts(dropna=False).head(20))
# Out:
# TRANSIT_DISTRICT
# NaN      5849
#  1.0       22
#  11.0      10
#  33.0      10
#  20.0      10
#  32.0       8
#  2.0        8
#  4.0        8
#  34.0       6
#  12.0       6
#  3.0        1
#  30.0       1
# Name: count, dtype: int64

# %% [markdown]
# Parece confirmarse que también es estructural

# %% [markdown]
# 2.   Analizo los que estan entre 10 y 20 por ciento
#
#
#
# | Variable          | % nulos |
# | ----------------- | ------- |
# | SUSP_RACE         | 19.2    |
# | SUSP_AGE_GROUP    | 19.2    |
# | SUSP_SEX          | 19.2    |
# | LOC_OF_OCCUR_DESC | 10.7    |

# %% [markdown]
# Todo sospechoso debería tener sexo, edad y raza registrados.

# %%
# Creamos una función para calcular el porcentaje de nulos en una columna, agrupando por una o más columnas
def nulos_por_grupo(df, grupo_cols, target_col):
    agrupar_nulos = (
        df.groupby(grupo_cols, observed=True)[target_col]
        .apply(lambda x: x.isnull().mean() * 100)
        .reset_index(name=f'porcentaje_nulos_{target_col}')
    )
    return agrupar_nulos

# %%
nulos_por_grupo(df,'BORO_NM','SUSP_RACE')
# Out:
#          BORO_NM  porcentaje_nulos_SUSP_RACE
# 0          BRONX                   21.905537
# 1       BROOKLYN                   22.415865
# 2      MANHATTAN                   11.607143
# 3         QUEENS                   17.444365
# 4  STATEN ISLAND                   17.647059

# %% [markdown]
# Apunta a MAR, porque BRONX y BROOKLYN parecen los BORO que tiene mas nulos, para que sea MCAR, deberían ser parecidas las proporciones.

# %%
nulos_por_grupo(df,'LAW_CAT_CD','SUSP_RACE')
# Out:
#     LAW_CAT_CD  porcentaje_nulos_SUSP_RACE
# 0       FELONY                   18.750000
# 1  MISDEMEANOR                   22.746331
# 2    VIOLATION                    5.760709

# %% [markdown]
# Apunta a MAR, porque FELONY y MISDEMEANOR parecen los LAW_CAT_CD que tiene mas nulos, para que sea MCAR, deberían ser parecidas las proporciones.

# %%
nulos_por_grupo(df,'BORO_NM','SUSP_AGE_GROUP')
# Out:
#          BORO_NM  porcentaje_nulos_SUSP_AGE_GROUP
# 0          BRONX                        21.905537
# 1       BROOKLYN                        22.415865
# 2      MANHATTAN                        11.607143
# 3         QUEENS                        17.444365
# 4  STATEN ISLAND                        17.647059

# %% [markdown]
# MAR como antes.

# %%
nulos_por_grupo(df,'LAW_CAT_CD','SUSP_AGE_GROUP')
# Out:
#     LAW_CAT_CD  porcentaje_nulos_SUSP_AGE_GROUP
# 0       FELONY                        18.750000
# 1  MISDEMEANOR                        22.746331
# 2    VIOLATION                         5.760709

# %% [markdown]
# MAR como antes, no parece MCAR

# %%
nulos_por_grupo(df,'BORO_NM','SUSP_AGE_GROUP')
# Out:
#          BORO_NM  porcentaje_nulos_SUSP_AGE_GROUP
# 0          BRONX                        21.905537
# 1       BROOKLYN                        22.415865
# 2      MANHATTAN                        11.607143
# 3         QUEENS                        17.444365
# 4  STATEN ISLAND                        17.647059

# %% [markdown]
# MAR identico

# %%
nulos_por_grupo(df,'BORO_NM','SUSP_SEX')
# Out:
#          BORO_NM  porcentaje_nulos_SUSP_SEX
# 0          BRONX                  21.905537
# 1       BROOKLYN                  22.415865
# 2      MANHATTAN                  11.607143
# 3         QUEENS                  17.444365
# 4  STATEN ISLAND                  17.647059

# %% [markdown]
# MAR

# %%
nulos_por_grupo(df,'LAW_CAT_CD','SUSP_SEX')
# Out:
#     LAW_CAT_CD  porcentaje_nulos_SUSP_SEX
# 0       FELONY                  18.750000
# 1  MISDEMEANOR                  22.746331
# 2    VIOLATION                   5.760709

# %% [markdown]
# MAR

# %%
nulos_por_grupo(df,'LAW_CAT_CD','LOC_OF_OCCUR_DESC')
# Out:
#     LAW_CAT_CD  porcentaje_nulos_LOC_OF_OCCUR_DESC
# 0       FELONY                            6.500000
# 1  MISDEMEANOR                           15.199161
# 2    VIOLATION                            6.203840

# %% [markdown]
# MAR, mas incidencia en misdemeanor

# %%
nulos_por_grupo(df,'BORO_NM','LOC_OF_OCCUR_DESC')
# Out:
#          BORO_NM  porcentaje_nulos_LOC_OF_OCCUR_DESC
# 0          BRONX                           10.667752
# 1       BROOKLYN                           10.336538
# 2      MANHATTAN                            9.226190
# 3         QUEENS                            9.404164
# 4  STATEN ISLAND                            8.235294

# %% [markdown]
# Compatible con MCAR, pero ya vi que es MAR

# %%
nulos_por_grupo(df, 'JURIS_DESC', 'CMPLNT_TO_TM')
# Out:
#                   JURIS_DESC  porcentaje_nulos_CMPLNT_TO_TM
# 0                    AMTRACK                       0.000000
# 1        DEPT OF CORRECTIONS                       0.000000
# 2   DISTRICT ATTORNEY OFFICE                      16.666667
# 3         HEALTH & HOSP CORP                      50.000000
# 4            MTA POLICE DEPT                      25.000000
# 5        N.Y. HOUSING POLICE                       4.643963
# 6           N.Y. POLICE DEPT                       5.884523
# 7          N.Y. STATE POLICE                     100.000000
# 8        N.Y. TRANSIT POLICE                      24.719101
# 9                      OTHER                      15.789474
# 10            PORT AUTHORITY                       4.347826

# %% [markdown]
# MAR

# %%
nulos_por_grupo(df, 'BORO_NM', 'CMPLNT_TO_TM')
# Out:
#          BORO_NM  porcentaje_nulos_CMPLNT_TO_TM
# 0          BRONX                      13.680782
# 1       BROOKLYN                       4.206731
# 2      MANHATTAN                       3.348214
# 3         QUEENS                       2.656138
# 4  STATEN ISLAND                       4.705882

# %% [markdown]
# MAR

# %%
nulos_por_grupo(df, 'LAW_CAT_CD', 'CMPLNT_TO_TM')
# Out:
#     LAW_CAT_CD  porcentaje_nulos_CMPLNT_TO_TM
# 0       FELONY                       3.791667
# 1  MISDEMEANOR                       8.700210
# 2    VIOLATION                       3.545052

# %% [markdown]
# MAR

# %% [markdown]
# CMPLNT_TO_DT es igual

# %% [markdown]
# entonces...
#
# | Variable           | Valores faltantes | % del total de valores |
# |-------------------|------------------:|------------------------:|
# | HADEVELOPT        | 5923             | 99.7% |
# | PARKS_NM          | 5915             | 99.6% |
# | TRANSIT_DISTRICT  | 5849             | 98.5% |
# | STATION_NAME      | 5849             | 98.5% |
# | HOUSING_PSA       | 5616             | 94.6% |
#
# Las variables HADEVELOPT, PARKS_NM, TRANSIT_DISTRICT, STATION_NAME y HOUSING_PSA presentan más del 90% de valores faltantes, podrían considerarse para su eliminación o redefinición de variable posiblemente binario. SUSP_RACE y SUSP_AGE_GROUP poseen alrededor del 19% de datos faltantes, por lo que podrían requerir tratamiento específico

# %% [markdown]
# **Outliers**

# %% [markdown]
# reviso la duracion desde la fecha  y hora donde se inicióo el incidente hasta que se terminó

# %%
#copio
df_aux1=df.copy()

df_aux1['CMPLNT_FR_DT'] = pd.to_datetime(df_aux1['CMPLNT_FR_DT'], errors='coerce')
df_aux1['CMPLNT_TO_DT'] = pd.to_datetime(df_aux1['CMPLNT_TO_DT'], errors='coerce')

df_aux1['CMPLNT_FR_TM'] = pd.to_timedelta(df_aux1['CMPLNT_FR_TM'])
df_aux1['CMPLNT_TO_TM'] = pd.to_timedelta(df_aux1['CMPLNT_TO_TM'])
df_aux1['DT_FR'] = df_aux1['CMPLNT_FR_DT'] + df_aux1['CMPLNT_FR_TM']
df_aux1['DT_TO'] = df_aux1['CMPLNT_TO_DT'] + df_aux1['CMPLNT_TO_TM']

df_aux1
# Out:
#        CMPLNT_NUM ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT    CMPLNT_FR_TM  \
# 69      318383739          60  BROOKLYN   2025-01-01 0 days 13:40:00
# 70      318305144         101    QUEENS   2025-12-30 0 days 10:34:00
# 95      318315162          63  BROOKLYN   2025-12-31 0 days 21:00:00
# 99      320247490          60  BROOKLYN   2025-11-20 0 days 20:00:00
# 108     318256135          60  BROOKLYN   2025-12-28 0 days 19:09:00
# ...           ...         ...       ...          ...             ...
# 132937  318224600          47     BRONX   2025-12-31 0 days 12:19:00
# 133020  321841618          45     BRONX   2025-12-20 0 days 08:00:00
# 133036  318462577          47     BRONX   2025-12-30 0 days 13:00:00
# 133089  320010904          52     BRONX   2025-12-01 0 days 22:35:00
# 133090  319309909          47     BRONX   2025-12-22 0 days 14:00:00
#
#        CMPLNT_TO_DT    CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT HOUSING_PSA  \
# 69       2026-01-01 0 days 13:45:00        COMPLETED        NaN         NaN
# 70       2025-12-30 0 days 21:00:00        COMPLETED        NaN         NaN
# 95       2025-12-31 0 days 21:30:00        COMPLETED        NaN         NaN
# 99       2025-11-20 0 days 21:00:00        COMPLETED        NaN         NaN
# 108      2025-12-28 0 days 19:10:00        COMPLETED        NaN         NaN
# ...             ...             ...              ...        ...         ...
# 132937   2025-12-31 0 days 12:25:00        COMPLETED        NaN         NaN
# 133020   2026-01-24 0 days 09:00:00        COMPLETED        NaN         NaN
# 133036   2026-01-06 0 days 15:00:00        COMPLETED        NaN         NaN
# 133089          NaT             NaT        COMPLETED        NaN         NaN
# 133090   2026-01-22 0 days 12:30:00        COMPLETED        NaN         NaN
#
#        JURISDICTION_CODE        JURIS_DESC KY_CD   LAW_CAT_CD  \
# 69                     0  N.Y. POLICE DEPT   578    VIOLATION
# 70                     0  N.Y. POLICE DEPT   341  MISDEMEANOR
# 95                     0  N.Y. POLICE DEPT   578    VIOLATION
# 99                     0  N.Y. POLICE DEPT   109       FELONY
# 108                    0  N.Y. POLICE DEPT   105       FELONY
# ...                  ...               ...   ...          ...
# 132937                 0  N.Y. POLICE DEPT   109       FELONY
# 133020                 0  N.Y. POLICE DEPT   578    VIOLATION
# 133036                 0  N.Y. POLICE DEPT   341  MISDEMEANOR
# 133089                 0  N.Y. POLICE DEPT   361  MISDEMEANOR
# 133090                 0  N.Y. POLICE DEPT   109       FELONY
#
#        LOC_OF_OCCUR_DESC                      OFNS_DESC PARKS_NM  \
# 69                INSIDE                  HARRASSMENT 2      NaN
# 70                INSIDE                  PETIT LARCENY      NaN
# 95              FRONT OF                  HARRASSMENT 2      NaN
# 99                INSIDE                  GRAND LARCENY      NaN
# 108               INSIDE                        ROBBERY      NaN
# ...                  ...                            ...      ...
# 132937          FRONT OF                  GRAND LARCENY      NaN
# 133020            INSIDE                  HARRASSMENT 2      NaN
# 133036            INSIDE                  PETIT LARCENY      NaN
# 133089            INSIDE  OFF. AGNST PUB ORD SENSBLTY &      NaN
# 133090            INSIDE                  GRAND LARCENY      NaN
#
#                      PATROL_BORO  PD_CD  \
# 69       PATROL BORO BKLYN SOUTH  638.0
# 70      PATROL BORO QUEENS SOUTH  352.0
# 95       PATROL BORO BKLYN SOUTH  638.0
# 99       PATROL BORO BKLYN SOUTH  412.0
# 108      PATROL BORO BKLYN SOUTH  399.0
# ...                          ...    ...
# 132937         PATROL BORO BRONX  457.0
# 133020         PATROL BORO BRONX  638.0
# 133036         PATROL BORO BRONX  349.0
# 133089         PATROL BORO BRONX  639.0
# 133090         PATROL BORO BRONX  432.0
#
#                                                   PD_DESC  \
# 69                                  HARASSMENT,SUBD 3,4,5
# 70      LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAG...
# 95                                  HARASSMENT,SUBD 3,4,5
# 99               LARCENY,GRAND FROM RESIDENCE, UNATTENDED
# 108                       ROBBERY,COMMERCIAL UNCLASSIFIED
# ...                                                   ...
# 132937  LARCENY,GRAND OF VEHICULAR/MOTORCYCLE ACCESSORIES
# 133020                              HARASSMENT,SUBD 3,4,5
# 133036                     LARCENY,PETIT OF LICENSE PLATE
# 133089                            AGGRAVATED HARASSMENT 2
# 133090       LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED
#
#                  PREM_TYP_DESC      RPT_DT STATION_NAME SUSP_AGE_GROUP  \
# 69              GROCERY/BODEGA  01/01/2026          NaN        UNKNOWN
# 70      RESIDENCE - APT. HOUSE  01/03/2026          NaN        UNKNOWN
# 95             RESIDENCE-HOUSE  01/01/2026          NaN        UNKNOWN
# 99      RESIDENCE - APT. HOUSE  02/11/2026          NaN          45-64
# 108                  FAST FOOD  01/02/2026          NaN        UNKNOWN
# ...                        ...         ...          ...            ...
# 132937                  STREET  01/01/2026          NaN        UNKNOWN
# 133020  RESIDENCE - APT. HOUSE  03/14/2026          NaN        UNKNOWN
# 133036        STORAGE FACILITY  01/06/2026          NaN            NaN
# 133089  RESIDENCE - APT. HOUSE  02/04/2026          NaN          25-44
# 133090     COMMERCIAL BUILDING  01/22/2026          NaN        UNKNOWN
#
#              SUSP_RACE SUSP_SEX TRANSIT_DISTRICT VIC_AGE_GROUP  \
# 69               BLACK        M              NaN         25-44
# 70             UNKNOWN        U              NaN         25-44
# 95             UNKNOWN        U              NaN         25-44
# 99               BLACK        F              NaN         45-64
# 108              BLACK        M              NaN         18-24
# ...                ...      ...              ...           ...
# 132937         UNKNOWN        U              NaN         25-44
# 133020  BLACK HISPANIC        U              NaN         45-64
# 133036             NaN      NaN              NaN           65+
# 133089         UNKNOWN        M              NaN       UNKNOWN
# 133090         UNKNOWN        U              NaN       UNKNOWN
#
#                         VIC_RACE VIC_SEX  X_COORD_CD  Y_COORD_CD   Latitude  \
# 69      ASIAN / PACIFIC ISLANDER       M      989419      149229  40,576284
# 70                         BLACK       M     1051811      156239   40,59527
# 95                         BLACK       F     1007120      166200  40,622837
# 99                         BLACK       M      988814      149158  40,576087
# 108     ASIAN / PACIFIC ISLANDER       M      985092      148865  40,575285
# ...                          ...     ...         ...         ...        ...
# 132937                     BLACK       F     1024351      260917   40,88275
# 133020            WHITE HISPANIC       F     1032451      257889  40,874398
# 133036                     WHITE       M     1028591      258644   40,87649
# 133089                   UNKNOWN       M     1018488      258415  40,875908
# 133090                   UNKNOWN       D     1021675      265917  40,896484
#
#          Longitude                  Lat_Lon      New Georeferenced Column  \
# 69      -73,981392  (40.576284, -73.981392)  POINT (-73.981392 40.576284)
# 70      -73,756726   (40.59527, -73.756726)   POINT (-73.756726 40.59527)
# 95      -73,917614  (40.622837, -73.917614)  POINT (-73.917614 40.622837)
# 99      -73,983569  (40.576087, -73.983569)  POINT (-73.983569 40.576087)
# 108     -73,996969  (40.575285, -73.996969)  POINT (-73.996969 40.575285)
# ...            ...                      ...                           ...
# 132937   -73,85498    (40.88275, -73.85498)    POINT (-73.85498 40.88275)
# 133020  -73,825707  (40.874398, -73.825707)  POINT (-73.825707 40.874398)
# 133036  -73,839661   (40.87649, -73.839661)   POINT (-73.839661 40.87649)
# 133089  -73,876194  (40.875908, -73.876194)  POINT (-73.876194 40.875908)
# 133090   -73,86463   (40.896484, -73.86463)   POINT (-73.86463 40.896484)
#
#                      DT_FR               DT_TO
# 69     2025-01-01 13:40:00 2026-01-01 13:45:00
# 70     2025-12-30 10:34:00 2025-12-30 21:00:00
# 95     2025-12-31 21:00:00 2025-12-31 21:30:00
# 99     2025-11-20 20:00:00 2025-11-20 21:00:00
# 108    2025-12-28 19:09:00 2025-12-28 19:10:00
# ...                    ...                 ...
# 132937 2025-12-31 12:19:00 2025-12-31 12:25:00
# 133020 2025-12-20 08:00:00 2026-01-24 09:00:00
# 133036 2025-12-30 13:00:00 2026-01-06 15:00:00
# 133089 2025-12-01 22:35:00                 NaT
# 133090 2025-12-22 14:00:00 2026-01-22 12:30:00
#
# [5939 rows x 38 columns]

# %%
df_aux1['duration'] = df_aux1['DT_TO'] - df_aux1['DT_FR']
df_aux1['duration_days'] = df_aux1['duration'].dt.total_seconds() /(3600*24)

# %%
df_aux1[df_aux1['duration_days']>200]
# Out:
#        CMPLNT_NUM ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT    CMPLNT_FR_TM  \
# 69      318383739          60  BROOKLYN   2025-01-01 0 days 13:40:00
# 509     322011929          63  BROOKLYN   2025-04-07 0 days 10:00:00
# 872     318901632          61  BROOKLYN   2025-01-14 0 days 19:50:00
# 985     321330562          60  BROOKLYN   2025-07-05 0 days 12:00:00
# 1035    319656373         101    QUEENS   2025-01-01 0 days 00:00:00
# ...           ...         ...       ...          ...             ...
# 131831  318341217          50     BRONX   2025-01-01 0 days 21:40:00
# 132225  320531798          47     BRONX   2025-06-01 0 days 00:01:00
# 132318  319910609          50     BRONX   2025-01-12 0 days 09:00:00
# 132544  318932821          47     BRONX   2025-03-15 0 days 08:00:00
# 132725  320746422          47     BRONX   2025-07-01 0 days 10:00:00
#
#        CMPLNT_TO_DT    CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT HOUSING_PSA  \
# 69       2026-01-01 0 days 13:45:00        COMPLETED        NaN         NaN
# 509      2025-12-31 0 days 23:59:00        COMPLETED        NaN         NaN
# 872      2026-01-14 0 days 20:00:00        COMPLETED        NaN         NaN
# 985      2026-03-03 0 days 12:00:00        COMPLETED        NaN         NaN
# 1035     2026-01-29 0 days 23:59:00        COMPLETED        NaN         NaN
# ...             ...             ...              ...        ...         ...
# 131831   2026-01-03 0 days 10:15:00        COMPLETED        NaN         NaN
# 132225   2026-02-16 0 days 12:20:00        COMPLETED        NaN         NaN
# 132318   2025-12-29 0 days 23:30:00        COMPLETED        NaN         NaN
# 132544   2026-01-10 0 days 08:00:00        COMPLETED        NaN         NaN
# 132725   2026-02-20 0 days 15:00:00        COMPLETED        NaN         NaN
#
#        JURISDICTION_CODE        JURIS_DESC KY_CD   LAW_CAT_CD  \
# 69                     0  N.Y. POLICE DEPT   578    VIOLATION
# 509                    0  N.Y. POLICE DEPT   341  MISDEMEANOR
# 872                    0  N.Y. POLICE DEPT   351  MISDEMEANOR
# 985                    0  N.Y. POLICE DEPT   578    VIOLATION
# 1035                   0  N.Y. POLICE DEPT   233  MISDEMEANOR
# ...                  ...               ...   ...          ...
# 131831                 0  N.Y. POLICE DEPT   361  MISDEMEANOR
# 132225                 0  N.Y. POLICE DEPT   112       FELONY
# 132318                 0  N.Y. POLICE DEPT   112       FELONY
# 132544                 0  N.Y. POLICE DEPT   109       FELONY
# 132725                 0  N.Y. POLICE DEPT   578    VIOLATION
#
#        LOC_OF_OCCUR_DESC                       OFNS_DESC PARKS_NM  \
# 69                INSIDE                   HARRASSMENT 2      NaN
# 509               INSIDE                   PETIT LARCENY      NaN
# 872               INSIDE  CRIMINAL MISCHIEF & RELATED OF      NaN
# 985               INSIDE                   HARRASSMENT 2      NaN
# 1035              INSIDE                      SEX CRIMES      NaN
# ...                  ...                             ...      ...
# 131831            INSIDE   OFF. AGNST PUB ORD SENSBLTY &      NaN
# 132225            INSIDE                     THEFT-FRAUD      NaN
# 132318            INSIDE                     THEFT-FRAUD      NaN
# 132544          FRONT OF                   GRAND LARCENY      NaN
# 132725            INSIDE                   HARRASSMENT 2      NaN
#
#                      PATROL_BORO  PD_CD  \
# 69       PATROL BORO BKLYN SOUTH  638.0
# 509      PATROL BORO BKLYN SOUTH  349.0
# 872      PATROL BORO BKLYN SOUTH  271.0
# 985      PATROL BORO BKLYN SOUTH  638.0
# 1035    PATROL BORO QUEENS SOUTH  170.0
# ...                          ...    ...
# 131831         PATROL BORO BRONX  639.0
# 132225         PATROL BORO BRONX  739.0
# 132318         PATROL BORO BRONX  739.0
# 132544         PATROL BORO BRONX  432.0
# 132725         PATROL BORO BRONX  638.0
#
#                                              PD_DESC           PREM_TYP_DESC  \
# 69                             HARASSMENT,SUBD 3,4,5          GROCERY/BODEGA
# 509                   LARCENY,PETIT OF LICENSE PLATE                  STREET
# 872                          TAMPERING 3,2, CRIMINAL                    BANK
# 985                            HARASSMENT,SUBD 3,4,5         RESIDENCE-HOUSE
# 1035                   SEXUAL MISCONDUCT,INTERCOURSE         RESIDENCE-HOUSE
# ...                                              ...                     ...
# 131831                       AGGRAVATED HARASSMENT 2  RESIDENCE - APT. HOUSE
# 132225                     FRAUD,UNCLASSIFIED-FELONY  RESIDENCE - APT. HOUSE
# 132318                     FRAUD,UNCLASSIFIED-FELONY  RESIDENCE - APT. HOUSE
# 132544  LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED         RESIDENCE-HOUSE
# 132725                         HARASSMENT,SUBD 3,4,5  RESIDENCE - APT. HOUSE
#
#             RPT_DT STATION_NAME SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  \
# 69      01/01/2026          NaN        UNKNOWN     BLACK        M
# 509     03/18/2026          NaN        UNKNOWN   UNKNOWN        U
# 872     01/14/2026          NaN          25-44     WHITE        M
# 985     03/04/2026          NaN        UNKNOWN     WHITE        M
# 1035    01/30/2026          NaN            <18   UNKNOWN        M
# ...            ...          ...            ...       ...      ...
# 131831  01/03/2026          NaN            65+     BLACK        F
# 132225  02/16/2026          NaN        UNKNOWN   UNKNOWN        U
# 132318  02/04/2026          NaN            NaN       NaN      NaN
# 132544  01/13/2026          NaN        UNKNOWN   UNKNOWN        U
# 132725  02/20/2026          NaN        UNKNOWN   UNKNOWN        U
#
#        TRANSIT_DISTRICT VIC_AGE_GROUP                  VIC_RACE VIC_SEX  \
# 69                  NaN         25-44  ASIAN / PACIFIC ISLANDER       M
# 509                 NaN         18-24            WHITE HISPANIC       F
# 872                 NaN       UNKNOWN                   UNKNOWN       D
# 985                 NaN         45-64                     WHITE       M
# 1035                NaN           <18                   UNKNOWN       F
# ...                 ...           ...                       ...     ...
# 131831              NaN         25-44                     BLACK       M
# 132225              NaN         25-44                     BLACK       M
# 132318              NaN         25-44            WHITE HISPANIC       M
# 132544              NaN           65+                     BLACK       F
# 132725              NaN         45-64            WHITE HISPANIC       F
#
#         X_COORD_CD  Y_COORD_CD        Latitude        Longitude  \
# 69          989419      149229       40,576284       -73,981392
# 509        1007231      164852       40,619138       -73,917219
# 872         997100      153241       40,587288       -73,953737
# 985         981274      148976        40,57559       -74,010712
# 1035       1053639      158980  40,60277623008  -73,75011736483
# ...            ...         ...             ...              ...
# 131831     1011349      258627       40,876514       -73,902008
# 132225     1034734      262749       40,887724       -73,817416
# 132318     1012305      260618       40,881976       -73,898545
# 132544     1028817      261200       40,883505       -73,838828
# 132725     1026365      263401       40,889558       -73,847681
#
#                                       Lat_Lon  \
# 69                    (40.576284, -73.981392)
# 509                   (40.619138, -73.917219)
# 872                   (40.587288, -73.953737)
# 985                    (40.57559, -74.010712)
# 1035    (40.6027762300781, -73.7501173648331)
# ...                                       ...
# 131831                (40.876514, -73.902008)
# 132225                (40.887724, -73.817416)
# 132318                (40.881976, -73.898545)
# 132544                (40.883505, -73.838828)
# 132725                (40.889558, -73.847681)
#
#                           New Georeferenced Column               DT_FR  \
# 69                    POINT (-73.981392 40.576284) 2025-01-01 13:40:00
# 509                   POINT (-73.917219 40.619138) 2025-04-07 10:00:00
# 872                   POINT (-73.953737 40.587288) 2025-01-14 19:50:00
# 985                    POINT (-74.010712 40.57559) 2025-07-05 12:00:00
# 1035    POINT (-73.7501173648331 40.6027762300781) 2025-01-01 00:00:00
# ...                                            ...                 ...
# 131831                POINT (-73.902008 40.876514) 2025-01-01 21:40:00
# 132225                POINT (-73.817416 40.887724) 2025-06-01 00:01:00
# 132318                POINT (-73.898545 40.881976) 2025-01-12 09:00:00
# 132544                POINT (-73.838828 40.883505) 2025-03-15 08:00:00
# 132725                POINT (-73.847681 40.889558) 2025-07-01 10:00:00
#
#                      DT_TO          duration  duration_days
# 69     2026-01-01 13:45:00 365 days 00:05:00     365.003472
# 509    2025-12-31 23:59:00 268 days 13:59:00     268.582639
# 872    2026-01-14 20:00:00 365 days 00:10:00     365.006944
# 985    2026-03-03 12:00:00 241 days 00:00:00     241.000000
# 1035   2026-01-29 23:59:00 393 days 23:59:00     393.999306
# ...                    ...               ...            ...
# 131831 2026-01-03 10:15:00 366 days 12:35:00     366.524306
# 132225 2026-02-16 12:20:00 260 days 12:19:00     260.513194
# 132318 2025-12-29 23:30:00 351 days 14:30:00     351.604167
# 132544 2026-01-10 08:00:00 301 days 00:00:00     301.000000
# 132725 2026-02-20 15:00:00 234 days 05:00:00     234.208333
#
# [544 rows x 40 columns]

# %%
df_aux1['duration_days'].describe(percentiles=[.25,.5,.75, .9, .95, .99])
# Out:
# count    5573.000000
# mean       53.456232
# std        99.112109
# min         0.000000
# 25%         0.020833
# 50%         2.415972
# 75%        57.000000
# 90%       192.613333
# 95%       363.402083
# 99%       365.762222
# max       441.811806
# Name: duration_days, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df_aux1['duration_days'])
plt.title('Boxplot de duración de incidentes (dias)')
plt.show()

# %% [markdown]
# Q1 (25%) = 0.0208 días
#
# Q2 (50%) = 2.4159 días
#
# Q3 (75%) = 57 días
#
# una distribución con una cola extremadamente pesada y un 75% todavía relativamente bajo frente a la cola extrema
#
# IQR=Q3−Q1=57−0.02≈56.98
#
# big inf:
# Q1−1.5⋅IQR≈0
#
# big sup:
# Q3+1.5⋅IQR=57+1.5x56.98=57+85x47=142.47
#
# caja: 0.02 - 57 días
#
# caja MUY grande en escala interna
#
# mediana: 2.41 días
#
# Outliers >142 dias
#
# Zona típica (bulk real):
#
# 0 a 2–3 días (muchísima concentración)
#
# mediana muy baja
#
# Zona intermedia:
#
# 3 a 57 días (dentro del 50% central)
#
# acá está la “variabilidad real del sistema”
#
# Cola extrema (outliers):
#
# mayor a 142 dias

# %% [markdown]
# # **Punto 2**
#
# **Applicación de técnicas de visualización:**
#
#
# *   Utilizar gráficos y técnicas de visualización aprendidos para ilustrar las principales características del dataset.
# *   Emplear el gráfico correcto en función del tipo de variable y del análisis que se está realizando.
# * Interpretar los resultados obtenidos a partir de las visualizaciones.

# %% [markdown]
# Muestro algunos gráficos de las variables que tienen que ver con datos personales de sospechosos y víctimas

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 12), sharey=True)
axes = axes.flatten()

for i, col in enumerate(['SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX']):
    sns.countplot(x=col, data=df, hue=col, palette='pastel', ax=axes[i])
    axes[i].tick_params(axis='x', labelrotation=90)

plt.suptitle('Distribución de categorías de las v. categóricas', fontsize=14)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
cross_tab = pd.crosstab(df['SUSP_RACE'], df['VIC_RACE'])
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='Blues')
plt.title('Tabla de contingencia (raza del sospechoso vs raza de la víctima)')
plt.xlabel('Raza de la víctima')
plt.ylabel('Raza del sospechoso')
plt.show()

# %%
plt.figure(figsize=(8, 5))
cross_tab = pd.crosstab(df['BORO_NM'], df['LAW_CAT_CD'])
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='Blues')
plt.title('Tabla de contingencia (Distrito vs Nivel del delito)')
plt.xlabel('Nivel del delito')
plt.ylabel('Distrito')
plt.show()

# %% [markdown]
# **Vamos a ver si hay relación entre algunas columnas**

# %%
# Funcion para calcular Cramér's V entre dos variables categóricas x e y
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r, k = confusion_matrix.shape
    return np.sqrt(chi2 / (n * min(k - 1, r - 1)))

# %%
cat_cols = [
    c for c in delito_cat_nom
    if (
        df[c].nunique(dropna=True) > 1
        and
        df[c].isna().mean() < 0.50
    )
]

# Matriz de asociación
v_mat = pd.DataFrame(
    index=cat_cols,
    columns=cat_cols,
    dtype=float
)

for c1 in cat_cols:
    for c2 in cat_cols:

        if c1 == c2:
            v_mat.loc[c1, c2] = 1.0
            continue

        mask = df[c1].notna() & df[c2].notna()

        if mask.sum() == 0:
            v_mat.loc[c1, c2] = np.nan
            continue

        v_mat.loc[c1, c2] = cramers_v(
            df.loc[mask, c1],
            df.loc[mask, c2]
        )


# Máscara para mostrar solo la mitad inferior
mask = np.triu(np.ones_like(v_mat, dtype=bool))

# Heatmap
plt.figure(figsize=(18, 15))

sns.heatmap(
    v_mat.astype(float),
    annot=True,
    fmt=".2f",
    cmap="YlOrRd",
    vmin=0,
    vmax=1,
    linewidths=0.5,
    mask=mask
)

plt.title("Cramér's V - Fuerza de asociación categórica-categórica")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()


# Top asociaciones más fuertes
corrs = (
    v_mat.where(~np.eye(v_mat.shape[0], dtype=bool))
         .stack()
         .sort_values(ascending=False)
)

print("Top 25 asociaciones:")
print(corrs.head(25))
# Out:
# Top 25 asociaciones:
# OFNS_DESC          PD_CD                1.000000
#                    KY_CD                1.000000
# JURIS_DESC         JURISDICTION_CODE    1.000000
# ADDR_PCT_CD        PATROL_BORO          1.000000
# LAW_CAT_CD         PD_CD                1.000000
# JURISDICTION_CODE  JURIS_DESC           1.000000
# PD_CD              KY_CD                1.000000
#                    PD_DESC              1.000000
#                    OFNS_DESC            1.000000
# PD_DESC            PD_CD                1.000000
# PATROL_BORO        ADDR_PCT_CD          1.000000
# PD_CD              LAW_CAT_CD           1.000000
# KY_CD              PD_CD                1.000000
#                    OFNS_DESC            1.000000
# ADDR_PCT_CD        BORO_NM              0.999656
# BORO_NM            ADDR_PCT_CD          0.999656
# PATROL_BORO        BORO_NM              0.999653
# BORO_NM            PATROL_BORO          0.999653
# KY_CD              LAW_CAT_CD           0.999648
# LAW_CAT_CD         KY_CD                0.999648
#                    PD_DESC              0.999394
# PD_DESC            LAW_CAT_CD           0.999394
#                    OFNS_DESC            0.999053
# OFNS_DESC          PD_DESC              0.999053
# PD_DESC            KY_CD                0.997967
# dtype: float64

# %% [markdown]
# 1.  Asociaciones casi perfectas (redundancia)
#
# | Variable 1 | Variable 2        | Cramér's V |
# | ---------- | ----------------- | ---------- |
# | OFNS_DESC  | PD_CD             | 1.00       |
# | OFNS_DESC  | KY_CD             | 1.00       |
# | JURIS_DESC | JURISDICTION_CODE | 1.00       |
# | PD_CD      | PD_DESC           | 1.00       |
# | PD_CD      | KY_CD             | 1.00       |
# | LAW_CAT_CD | PD_CD             | 1.00       |
# | LAW_CAT_CD | KY_CD             | 0.9996     |
#
# Correspondencia 1 a 1
#
# 2.  Asociaciones geográficas
#
# | Variable 1  | Variable 2  | Cramér's V |
# | ----------- | ----------- | ---------- |
# | ADDR_PCT_CD | BORO_NM     | 0.9997     |
# | ADDR_PCT_CD | PATROL_BORO | 1.00       |
# | BORO_NM     | PATROL_BORO | 0.9997     |
#
# Precinto corresponde a un borough y a una zona de patrullaje determinada
#
# 3. Asociaciones interesantes
#
# | Variable 1    | Variable 2 | Cramér's V |
# | ------------- | ---------- | ---------- |
# | VIC_SEX       | PD_CD      | 0.61       |
# | VIC_SEX       | PD_DESC    | 0.61       |
# | PREM_TYP_DESC | JURIS_DESC | 0.60       |
# | SUSP_SEX      | PD_CD      | 0.57       |
# | SUSP_SEX      | PD_DESC    | 0.57       |
#
# son interesantes porque no son equivalencias directas.
#
# Por ejemplo:
# Algunos tipos de delito pueden ocurrir más frecuentemente sobre víctimas de determinado sexo.
# Algunos tipos de establecimiento (PREM_TYP_DESC) pueden estar asociados a ciertas jurisdicciones.
#
#
# entonces variables redundantes:
#
#
# PD_CD
# PD_DESC
# KY_CD
# OFNS_DESC
#
# dejaría  para el procesamiento LAW_CAT_CD
#
#
# y
#
#
# JURISDICTION_CODE
# JURIS_DESC
#
# dejaría JURISDICTION_CODE
#
#
# y
#
# ADDR_PCT_CD
# BORO_NM
# PATROL_BORO
#
# y dejaria para el procesamiento ADDR_PCT_CD

# %%
def print_categorias(dataframe, columna):
    print(f"Cantidad de categorías que tiene la variable '{columna}': {dataframe[columna].nunique()}\n")
    print(f"Nombres de categorías presentes en la variable '{columna}': {dataframe[columna].unique()}\n")

    freq = dataframe[columna].value_counts()
    freq_rel = dataframe[columna].value_counts(normalize=True).mul(100).round(2)

    freq_tabla = pd.DataFrame({'Frecuencia absoluta': freq, 'Frecuencia relativa (%)': freq_rel})

    print(f"Frecuencias de cada categoría en la variable '{columna}':\n{freq_tabla}\n")

# %%
print_categorias(df,'OFNS_DESC')
# Out:
# Cantidad de categorías que tiene la variable 'OFNS_DESC': 39
#
# Nombres de categorías presentes en la variable 'OFNS_DESC': ['HARRASSMENT 2', 'PETIT LARCENY', 'GRAND LARCENY', 'ROBBERY', 'OFFENSES AGAINST THE PERSON', ..., 'OFFENSES AGAINST PUBLIC SAFETY', 'INTOXICATED & IMPAIRED DRIVING', 'OFFENSES RELATED TO CHILDREN', 'PROSTITUTION & RELATED OFFENSES', 'ANTICIPATORY OFFENSES']
# Length: 39
# Categories (39, object): ['ADMINISTRATIVE CODE', 'ANTICIPATORY OFFENSES', 'ARSON', 'ASSAULT 3 & RELATED OFFENSES', ..., 'SEX CRIMES', 'THEFT-FRAUD', 'UNAUTHORIZED USE OF A VEHICLE', 'VEHICLE AND TRAFFIC LAWS']
#
# Frecuencias de cada categoría en la variable 'OFNS_DESC':
#                                   Frecuencia absoluta  Frecuencia relativa (%)
# OFNS_DESC
# PETIT LARCENY                                    1551                    26.12
# GRAND LARCENY                                    1230                    20.71
# HARRASSMENT 2                                     674                    11.35
# OFF. AGNST PUB ORD SENSBLTY &                     321                     5.40
# ASSAULT 3 & RELATED OFFENSES                      281                     4.73
# CRIMINAL MISCHIEF & RELATED OF                    227                     3.82
# SEX CRIMES                                        225                     3.79
# THEFT-FRAUD                                       208                     3.50
# MISCELLANEOUS PENAL LAW                           169                     2.85
# FELONY ASSAULT                                    148                     2.49
# FRAUDS                                            117                     1.97
# RAPE                                              109                     1.84
# BURGLARY                                           94                     1.58
# GRAND LARCENY OF MOTOR VEHICLE                     90                     1.52
# FORGERY                                            74                     1.25
# DANGEROUS DRUGS                                    61                     1.03
# UNAUTHORIZED USE OF A VEHICLE                      59                     0.99
# OFFENSES AGAINST PUBLIC ADMINI                     41                     0.69
# OTHER OFFENSES RELATED TO THEFT                    38                     0.64
# VEHICLE AND TRAFFIC LAWS                           35                     0.59
# POSSESSION OF STOLEN PROPERTY                      30                     0.51
# OTHER STATE LAWS                                   25                     0.42
# CRIMINAL TRESPASS                                  24                     0.40
# ROBBERY                                            24                     0.40
# ARSON                                              14                     0.24
# OFFENSES AGAINST THE PERSON                        11                     0.19
# DANGEROUS WEAPONS                                  10                     0.17
# OTHER STATE LAWS (NON PENAL LAW)                    9                     0.15
# ADMINISTRATIVE CODE                                 9                     0.15
# PETIT LARCENY OF MOTOR VEHICLE                      7                     0.12
# MURDER & NON-NEGL. MANSLAUGHTER                     7                     0.12
# OFFENSES INVOLVING FRAUD                            5                     0.08
# KIDNAPPING & RELATED OFFENSES                       4                     0.07
# FRAUDULENT ACCOSTING                                3                     0.05
# ANTICIPATORY OFFENSES                               1                     0.02
# OFFENSES AGAINST PUBLIC SAFETY                      1                     0.02
# INTOXICATED & IMPAIRED DRIVING                      1                     0.02
# OFFENSES RELATED TO CHILDREN                        1                     0.02
# PROSTITUTION & RELATED OFFENSES                     1                     0.02

# %%
df['OFNS_DESC'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='OFNS_DESC'>

# %%
print_categorias(df,'LAW_CAT_CD')
# Out:
# Cantidad de categorías que tiene la variable 'LAW_CAT_CD': 3
#
# Nombres de categorías presentes en la variable 'LAW_CAT_CD': ['VIOLATION', 'MISDEMEANOR', 'FELONY']
# Categories (3, object): ['FELONY', 'MISDEMEANOR', 'VIOLATION']
#
# Frecuencias de cada categoría en la variable 'LAW_CAT_CD':
#              Frecuencia absoluta  Frecuencia relativa (%)
# LAW_CAT_CD
# MISDEMEANOR                 2862                    48.19
# FELONY                      2400                    40.41
# VIOLATION                    677                    11.40

# %%
df['LAW_CAT_CD'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='LAW_CAT_CD'>

# %%
print_categorias(df,'BORO_NM')
# Out:
# Cantidad de categorías que tiene la variable 'BORO_NM': 5
#
# Nombres de categorías presentes en la variable 'BORO_NM': ['BROOKLYN', 'QUEENS', 'STATEN ISLAND', NaN, 'MANHATTAN', 'BRONX']
# Categories (5, object): ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
#
# Frecuencias de cada categoría en la variable 'BORO_NM':
#                Frecuencia absoluta  Frecuencia relativa (%)
# BORO_NM
# BROOKLYN                      1664                    28.28
# QUEENS                        1393                    23.67
# MANHATTAN                     1344                    22.84
# BRONX                         1228                    20.87
# STATEN ISLAND                  255                     4.33

# %%
df['BORO_NM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BORO_NM'>

# %%
# genero un df para graficar...despues procesaremos
df_aux=df.copy()
df_aux['CMPLNT_FR_DT'] = pd.to_datetime(df_aux['CMPLNT_FR_DT'])
df_aux['anio'] = df_aux['CMPLNT_FR_DT'].dt.year
df_aux['mes'] = df_aux['CMPLNT_FR_DT'].dt.month
df_aux['dia_semana'] = df_aux['CMPLNT_FR_DT'].dt.dayofweek

# %%
print_categorias(df_aux,'mes')
# Out:
# Cantidad de categorías que tiene la variable 'mes': 12
#
# Nombres de categorías presentes en la variable 'mes': [ 1 12 11 10  7  9  8  6  4  2  3  5]
#
# Frecuencias de cada categoría en la variable 'mes':
#      Frecuencia absoluta  Frecuencia relativa (%)
# mes
# 12                  2944                    49.57
# 11                   841                    14.16
# 10                   498                     8.39
# 1                    306                     5.15
# 9                    302                     5.09
# 8                    237                     3.99
# 7                    179                     3.01
# 6                    143                     2.41
# 2                    140                     2.36
# 3                    140                     2.36
# 5                    117                     1.97
# 4                     92                     1.55

# %%
sns.histplot(df_aux['mes'], bins=12)
# Out:
# <Axes: xlabel='mes', ylabel='Count'>

# %%
df_aux['hora'] = pd.to_datetime(
    df_aux['CMPLNT_FR_TM'],
    format='%H:%M:%S'
).dt.hour

# %%
print_categorias(df_aux,'hora')
# Out:
# Cantidad de categorías que tiene la variable 'hora': 24
#
# Nombres de categorías presentes en la variable 'hora': [13 10 21 20 19 11 15  3 12 18  9  1 14  0 16  4  8 22 17  7  5  6 23  2]
#
# Frecuencias de cada categoría en la variable 'hora':
#       Frecuencia absoluta  Frecuencia relativa (%)
# hora
# 12                    640                    10.78
# 0                     554                     9.33
# 15                    416                     7.00
# 10                    354                     5.96
# 9                     345                     5.81
# 14                    333                     5.61
# 8                     329                     5.54
# 11                    309                     5.20
# 13                    305                     5.14
# 16                    290                     4.88
# 17                    290                     4.88
# 18                    275                     4.63
# 19                    223                     3.75
# 21                    199                     3.35
# 20                    196                     3.30
# 23                    175                     2.95
# 22                    162                     2.73
# 7                     139                     2.34
# 1                      91                     1.53
# 2                      85                     1.43
# 6                      71                     1.20
# 5                      55                     0.93
# 4                      52                     0.88
# 3                      51                     0.86

# %%
sns.histplot(df_aux['hora'], bins=24)
# Out:
# <Axes: xlabel='hora', ylabel='Count'>

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    data=df_aux,
    x='LAW_CAT_CD',
    y='hora'
)

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    data=df_aux,
    x='LAW_CAT_CD',
    y='dia_semana'
)

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    data=df_aux,
    x='LAW_CAT_CD',
    y='mes'
)

plt.show()

# %%
df_sample = df_aux.sample(
    n=min(600, len(df_aux)),
    random_state=42
)

plt.figure(figsize=(15, 4))

sns.swarmplot(
    x=df_sample['hora'],
    color='turquoise',
    size=2
)

ax = plt.gca()

ax.set_xticks(np.arange(0, 24, 1))
ax.grid(axis='x', linestyle='--', alpha=0.4)

ax.set_yticks([])
ax.set_ylabel("")
ax.set_xlabel("Hora del incidente")

sns.despine(left=True)

plt.title("Swarmplot de la hora del incidente")
plt.tight_layout()
plt.show()

# %%
df_sample = df_aux.sample(
    n=min(500, len(df_aux)),
    random_state=42
)

plt.figure(figsize=(15, 4))

sns.swarmplot(
    x=df_sample['dia_semana'],
    color='turquoise',
    size=2
)

ax = plt.gca()

ax.set_xticks(np.arange(0, 7, 1))
ax.grid(axis='x', linestyle='--', alpha=0.4)

ax.set_yticks([])
ax.set_ylabel("")
ax.set_xlabel("dia de la semana del incidente")

sns.despine(left=True)


plt.title("Swarmplot del dia de la semana del incidente")
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Punto 3**
#
# **Plantear un posible problema de ML supervisado a partir de los datos elegidos**
#
# *   Describir el problema de clasificación o regresión.
# *   Definir la variable target.

# %% [markdown]
# El problema de ML supervisado será de clasificacion y el target será el atributo categorico: LAW_CAT_CD (indica categoría del nivel del delito).

# %% [markdown]
# #**Punto 4**
#
# **Preprocesamiento y limpieza del dataset**
#
# * Realizar una limpieza general del dataset, eliminando o corrigiendo datos inconsistentes o relevantes.
# * Realizar el split del dataset.
# * Identificar y tratar los valores faltantes en el dataset.
# * Detectar y manejar los outliers utilizando técnicas estadísticas o visuales apropiadas.
# * Escalar / normalizar los features.

# %% [markdown]
# recordatorio:
# ![image.png](data:image/png;base64,...)

# %%
df_aux3=df.copy()

# %% [markdown]
# otro repaso:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# redefino algunas features o elimino con >90 por ciento nulos que son estructurales y elimino id CMPLNT_NUM

# %% [markdown]
# Debido a que estas variables presentaban más del 90% de valores nulos, se reemplazaron por indicadores binarios de presencia (IN_PARK, IN_TRANSIT, IN_HOUSING), conservando la información relevante y evitando trabajar con columnas de alta cardinalidad y escasa completitud.

# %%
df_aux3['IN_PARK'] = df_aux3['PARKS_NM'].notna().astype(int)

df_aux3['IN_TRANSIT'] = (
    df_aux3['STATION_NAME'].notna() |
    df_aux3['TRANSIT_DISTRICT'].notna()
).astype(int)

df_aux3['IN_HOUSING'] = (
    df_aux3['HOUSING_PSA'].notna() |
    df_aux3['HADEVELOPT'].notna()
).astype(int)

df_aux3 = df_aux3.drop(columns=["CMPLNT_NUM","HOUSING_PSA","TRANSIT_DISTRICT","PARKS_NM","HADEVELOPT","STATION_NAME"])

# %%
df_aux3
# Out:
#        ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 69              60  BROOKLYN   01/01/2025     13:40:00   01/01/2026
# 70             101    QUEENS   12/30/2025     10:34:00   12/30/2025
# 95              63  BROOKLYN   12/31/2025     21:00:00   12/31/2025
# 99              60  BROOKLYN   11/20/2025     20:00:00   11/20/2025
# 108             60  BROOKLYN   12/28/2025     19:09:00   12/28/2025
# ...            ...       ...          ...          ...          ...
# 132937          47     BRONX   12/31/2025     12:19:00   12/31/2025
# 133020          45     BRONX   12/20/2025     08:00:00   01/24/2026
# 133036          47     BRONX   12/30/2025     13:00:00   01/06/2026
# 133089          52     BRONX   12/01/2025     22:35:00          NaN
# 133090          47     BRONX   12/22/2025     14:00:00   01/22/2026
#
#        CMPLNT_TO_TM CRM_ATPT_CPTD_CD JURISDICTION_CODE        JURIS_DESC  \
# 69         13:45:00        COMPLETED                 0  N.Y. POLICE DEPT
# 70         21:00:00        COMPLETED                 0  N.Y. POLICE DEPT
# 95         21:30:00        COMPLETED                 0  N.Y. POLICE DEPT
# 99         21:00:00        COMPLETED                 0  N.Y. POLICE DEPT
# 108        19:10:00        COMPLETED                 0  N.Y. POLICE DEPT
# ...             ...              ...               ...               ...
# 132937     12:25:00        COMPLETED                 0  N.Y. POLICE DEPT
# 133020     09:00:00        COMPLETED                 0  N.Y. POLICE DEPT
# 133036     15:00:00        COMPLETED                 0  N.Y. POLICE DEPT
# 133089          NaN        COMPLETED                 0  N.Y. POLICE DEPT
# 133090     12:30:00        COMPLETED                 0  N.Y. POLICE DEPT
#
#        KY_CD   LAW_CAT_CD LOC_OF_OCCUR_DESC                      OFNS_DESC  \
# 69       578    VIOLATION            INSIDE                  HARRASSMENT 2
# 70       341  MISDEMEANOR            INSIDE                  PETIT LARCENY
# 95       578    VIOLATION          FRONT OF                  HARRASSMENT 2
# 99       109       FELONY            INSIDE                  GRAND LARCENY
# 108      105       FELONY            INSIDE                        ROBBERY
# ...      ...          ...               ...                            ...
# 132937   109       FELONY          FRONT OF                  GRAND LARCENY
# 133020   578    VIOLATION            INSIDE                  HARRASSMENT 2
# 133036   341  MISDEMEANOR            INSIDE                  PETIT LARCENY
# 133089   361  MISDEMEANOR            INSIDE  OFF. AGNST PUB ORD SENSBLTY &
# 133090   109       FELONY            INSIDE                  GRAND LARCENY
#
#                      PATROL_BORO  PD_CD  \
# 69       PATROL BORO BKLYN SOUTH  638.0
# 70      PATROL BORO QUEENS SOUTH  352.0
# 95       PATROL BORO BKLYN SOUTH  638.0
# 99       PATROL BORO BKLYN SOUTH  412.0
# 108      PATROL BORO BKLYN SOUTH  399.0
# ...                          ...    ...
# 132937         PATROL BORO BRONX  457.0
# 133020         PATROL BORO BRONX  638.0
# 133036         PATROL BORO BRONX  349.0
# 133089         PATROL BORO BRONX  639.0
# 133090         PATROL BORO BRONX  432.0
#
#                                                   PD_DESC  \
# 69                                  HARASSMENT,SUBD 3,4,5
# 70      LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAG...
# 95                                  HARASSMENT,SUBD 3,4,5
# 99               LARCENY,GRAND FROM RESIDENCE, UNATTENDED
# 108                       ROBBERY,COMMERCIAL UNCLASSIFIED
# ...                                                   ...
# 132937  LARCENY,GRAND OF VEHICULAR/MOTORCYCLE ACCESSORIES
# 133020                              HARASSMENT,SUBD 3,4,5
# 133036                     LARCENY,PETIT OF LICENSE PLATE
# 133089                            AGGRAVATED HARASSMENT 2
# 133090       LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED
#
#                  PREM_TYP_DESC      RPT_DT SUSP_AGE_GROUP       SUSP_RACE  \
# 69              GROCERY/BODEGA  01/01/2026        UNKNOWN           BLACK
# 70      RESIDENCE - APT. HOUSE  01/03/2026        UNKNOWN         UNKNOWN
# 95             RESIDENCE-HOUSE  01/01/2026        UNKNOWN         UNKNOWN
# 99      RESIDENCE - APT. HOUSE  02/11/2026          45-64           BLACK
# 108                  FAST FOOD  01/02/2026        UNKNOWN           BLACK
# ...                        ...         ...            ...             ...
# 132937                  STREET  01/01/2026        UNKNOWN         UNKNOWN
# 133020  RESIDENCE - APT. HOUSE  03/14/2026        UNKNOWN  BLACK HISPANIC
# 133036        STORAGE FACILITY  01/06/2026            NaN             NaN
# 133089  RESIDENCE - APT. HOUSE  02/04/2026          25-44         UNKNOWN
# 133090     COMMERCIAL BUILDING  01/22/2026        UNKNOWN         UNKNOWN
#
#        SUSP_SEX VIC_AGE_GROUP                  VIC_RACE VIC_SEX  X_COORD_CD  \
# 69            M         25-44  ASIAN / PACIFIC ISLANDER       M      989419
# 70            U         25-44                     BLACK       M     1051811
# 95            U         25-44                     BLACK       F     1007120
# 99            F         45-64                     BLACK       M      988814
# 108           M         18-24  ASIAN / PACIFIC ISLANDER       M      985092
# ...         ...           ...                       ...     ...         ...
# 132937        U         25-44                     BLACK       F     1024351
# 133020        U         45-64            WHITE HISPANIC       F     1032451
# 133036      NaN           65+                     WHITE       M     1028591
# 133089        M       UNKNOWN                   UNKNOWN       M     1018488
# 133090        U       UNKNOWN                   UNKNOWN       D     1021675
#
#         Y_COORD_CD   Latitude   Longitude                  Lat_Lon  \
# 69          149229  40,576284  -73,981392  (40.576284, -73.981392)
# 70          156239   40,59527  -73,756726   (40.59527, -73.756726)
# 95          166200  40,622837  -73,917614  (40.622837, -73.917614)
# 99          149158  40,576087  -73,983569  (40.576087, -73.983569)
# 108         148865  40,575285  -73,996969  (40.575285, -73.996969)
# ...            ...        ...         ...                      ...
# 132937      260917   40,88275   -73,85498    (40.88275, -73.85498)
# 133020      257889  40,874398  -73,825707  (40.874398, -73.825707)
# 133036      258644   40,87649  -73,839661   (40.87649, -73.839661)
# 133089      258415  40,875908  -73,876194  (40.875908, -73.876194)
# 133090      265917  40,896484   -73,86463   (40.896484, -73.86463)
#
#             New Georeferenced Column  IN_PARK  IN_TRANSIT  IN_HOUSING
# 69      POINT (-73.981392 40.576284)        0           0           0
# 70       POINT (-73.756726 40.59527)        0           0           0
# 95      POINT (-73.917614 40.622837)        0           0           0
# 99      POINT (-73.983569 40.576087)        0           0           0
# 108     POINT (-73.996969 40.575285)        0           0           0
# ...                              ...      ...         ...         ...
# 132937    POINT (-73.85498 40.88275)        0           0           0
# 133020  POINT (-73.825707 40.874398)        0           0           0
# 133036   POINT (-73.839661 40.87649)        0           0           0
# 133089  POINT (-73.876194 40.875908)        0           0           0
# 133090   POINT (-73.86463 40.896484)        0           0           0
#
# [5939 rows x 33 columns]

# %% [markdown]
# saco redundantes obtenidos de antes

# %%
df_aux3 = df_aux3.drop(columns=[
    'PD_CD',
    'KY_CD',
    'PD_DESC',
    'OFNS_DESC',
    'JURIS_DESC',
    'BORO_NM',
    'PATROL_BORO'
])

# %% [markdown]
# Saco también las columnas con baja correlación con la variable target:
#
#
# *   0.09 'LOC_OF_OCCUR_DESC'
# *   0.07 'JURISDICTION_CODE'
# *   0.07 'PATROL_BORO' (ya fue eliminada en el paso anterior)
#
# Se entiende que estas variables no aportan a la predicción que se busca

# %%
df_aux3 = df_aux3.drop(columns=[
    'LOC_OF_OCCUR_DESC',
    'JURISDICTION_CODE'
])

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 69              60   01/01/2025     13:40:00   01/01/2026     13:45:00
# 70             101   12/30/2025     10:34:00   12/30/2025     21:00:00
# 95              63   12/31/2025     21:00:00   12/31/2025     21:30:00
# 99              60   11/20/2025     20:00:00   11/20/2025     21:00:00
# 108             60   12/28/2025     19:09:00   12/28/2025     19:10:00
# ...            ...          ...          ...          ...          ...
# 132937          47   12/31/2025     12:19:00   12/31/2025     12:25:00
# 133020          45   12/20/2025     08:00:00   01/24/2026     09:00:00
# 133036          47   12/30/2025     13:00:00   01/06/2026     15:00:00
# 133089          52   12/01/2025     22:35:00          NaN          NaN
# 133090          47   12/22/2025     14:00:00   01/22/2026     12:30:00
#
#        CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC      RPT_DT  \
# 69            COMPLETED    VIOLATION          GROCERY/BODEGA  01/01/2026
# 70            COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE  01/03/2026
# 95            COMPLETED    VIOLATION         RESIDENCE-HOUSE  01/01/2026
# 99            COMPLETED       FELONY  RESIDENCE - APT. HOUSE  02/11/2026
# 108           COMPLETED       FELONY               FAST FOOD  01/02/2026
# ...                 ...          ...                     ...         ...
# 132937        COMPLETED       FELONY                  STREET  01/01/2026
# 133020        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE  03/14/2026
# 133036        COMPLETED  MISDEMEANOR        STORAGE FACILITY  01/06/2026
# 133089        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE  02/04/2026
# 133090        COMPLETED       FELONY     COMMERCIAL BUILDING  01/22/2026
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036            NaN             NaN      NaN           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  X_COORD_CD  Y_COORD_CD   Latitude  \
# 69      ASIAN / PACIFIC ISLANDER       M      989419      149229  40,576284
# 70                         BLACK       M     1051811      156239   40,59527
# 95                         BLACK       F     1007120      166200  40,622837
# 99                         BLACK       M      988814      149158  40,576087
# 108     ASIAN / PACIFIC ISLANDER       M      985092      148865  40,575285
# ...                          ...     ...         ...         ...        ...
# 132937                     BLACK       F     1024351      260917   40,88275
# 133020            WHITE HISPANIC       F     1032451      257889  40,874398
# 133036                     WHITE       M     1028591      258644   40,87649
# 133089                   UNKNOWN       M     1018488      258415  40,875908
# 133090                   UNKNOWN       D     1021675      265917  40,896484
#
#          Longitude                  Lat_Lon      New Georeferenced Column  \
# 69      -73,981392  (40.576284, -73.981392)  POINT (-73.981392 40.576284)
# 70      -73,756726   (40.59527, -73.756726)   POINT (-73.756726 40.59527)
# 95      -73,917614  (40.622837, -73.917614)  POINT (-73.917614 40.622837)
# 99      -73,983569  (40.576087, -73.983569)  POINT (-73.983569 40.576087)
# 108     -73,996969  (40.575285, -73.996969)  POINT (-73.996969 40.575285)
# ...            ...                      ...                           ...
# 132937   -73,85498    (40.88275, -73.85498)    POINT (-73.85498 40.88275)
# 133020  -73,825707  (40.874398, -73.825707)  POINT (-73.825707 40.874398)
# 133036  -73,839661   (40.87649, -73.839661)   POINT (-73.839661 40.87649)
# 133089  -73,876194  (40.875908, -73.876194)  POINT (-73.876194 40.875908)
# 133090   -73,86463   (40.896484, -73.86463)   POINT (-73.86463 40.896484)
#
#         IN_PARK  IN_TRANSIT  IN_HOUSING
# 69            0           0           0
# 70            0           0           0
# 95            0           0           0
# 99            0           0           0
# 108           0           0           0
# ...         ...         ...         ...
# 132937        0           0           0
# 133020        0           0           0
# 133036        0           0           0
# 133089        0           0           0
# 133090        0           0           0
#
# [5939 rows x 24 columns]

# %% [markdown]
# Lo puedo hacer antes del split porque no uso ningun estadistico. Por eso no hay riesgo de data leakage.

# %%
validos = ["<18", "18-24", "25-44", "45-64", "65+"]
df_aux3['SUSP_AGE_GROUP'] = df_aux3['SUSP_AGE_GROUP'].astype(str)

df_aux3['SUSP_AGE_GROUP'] = df_aux3['SUSP_AGE_GROUP'].apply(
    lambda x: x if x in validos else "UNKNOWN"
)
df_aux3['SUSP_AGE_GROUP'] = df_aux3['SUSP_AGE_GROUP'].replace("nan", "UNKNOWN")

# %%
df_aux3['SUSP_AGE_GROUP'].value_counts()
# Out:
# SUSP_AGE_GROUP
# UNKNOWN    3884
# 25-44      1226
# 45-64       451
# 18-24       222
# <18          88
# 65+          68
# Name: count, dtype: int64

# %%
validos = ["<18", "18-24", "25-44", "45-64", "65+"]
df_aux3['VIC_AGE_GROUP'] = df_aux3['VIC_AGE_GROUP'].astype(str)

df_aux3['VIC_AGE_GROUP'] = df_aux3['VIC_AGE_GROUP'].apply(
    lambda x: x if x in validos else "UNKNOWN"
)
df_aux3['VIC_AGE_GROUP'] = df_aux3['VIC_AGE_GROUP'].replace("nan", "UNKNOWN")

# %%
df_aux3.VIC_AGE_GROUP.value_counts()
# Out:
# VIC_AGE_GROUP
# 25-44      2228
# 45-64      1284
# UNKNOWN    1119
# 65+         594
# 18-24       433
# <18         281
# Name: count, dtype: int64

# %%
validos = ["<18", "18-24", "25-44", "45-64", "65+"]
df_aux3['VIC_AGE_GROUP'] = df_aux3['VIC_AGE_GROUP'].astype(str)

df_aux3['VIC_AGE_GROUP'] = df_aux3['VIC_AGE_GROUP'].apply(
    lambda x: x if x in validos else "UNKNOWN"
)
df_aux3['VIC_AGE_GROUP'] = df_aux3['VIC_AGE_GROUP'].replace("nan", "UNKNOWN")

# %%
df_aux3['VIC_AGE_GROUP'].value_counts()
# Out:
# VIC_AGE_GROUP
# 25-44      2228
# 45-64      1284
# UNKNOWN    1119
# 65+         594
# 18-24       433
# <18         281
# Name: count, dtype: int64

# %%
validos = ["BLACK", "WHITE HISPANIC","WHITE", "ASIAN / PACIFIC ISLANDER", "BLACK HISPANIC", "AMERICAN INDIAN/ALASKAN NATIVE"]
df_aux3['VIC_RACE'] = df_aux3['VIC_RACE'].astype(str)

df_aux3['VIC_RACE'] = df_aux3['VIC_RACE'].apply(
    lambda x: x if x in validos else "UNKNOWN"
)
df_aux3['VIC_RACE'] = df_aux3['VIC_RACE'].replace("nan", "UNKNOWN")

# %%
df_aux3.VIC_RACE.value_counts()
# Out:
# VIC_RACE
# BLACK                             1508
# UNKNOWN                           1294
# WHITE                             1238
# WHITE HISPANIC                     979
# ASIAN / PACIFIC ISLANDER           626
# BLACK HISPANIC                     267
# AMERICAN INDIAN/ALASKAN NATIVE      27
# Name: count, dtype: int64

# %%
validos = ["BLACK", "WHITE HISPANIC","WHITE", "ASIAN / PACIFIC ISLANDER", "BLACK HISPANIC", "AMERICAN INDIAN/ALASKAN NATIVE"]
df_aux3['SUSP_RACE'] = df_aux3['SUSP_RACE'].astype(str)

df_aux3['SUSP_RACE'] = df_aux3['SUSP_RACE'].apply(
    lambda x: x if x in validos else "UNKNOWN"
)
df_aux3['SUSP_RACE'] = df_aux3['SUSP_RACE'].replace("nan", "UNKNOWN")

# %%
df_aux3['SUSP_RACE'].value_counts()
# Out:
# SUSP_RACE
# UNKNOWN                           3611
# BLACK                              995
# WHITE HISPANIC                     552
# WHITE                              390
# ASIAN / PACIFIC ISLANDER           194
# BLACK HISPANIC                     188
# AMERICAN INDIAN/ALASKAN NATIVE       9
# Name: count, dtype: int64

# %%
#df_aux3['LOC_OF_OCCUR_DESC'] = (
#    df_aux3['LOC_OF_OCCUR_DESC']
#    .cat.add_categories(['UNKNOWN'])
#    .fillna('UNKNOWN')
#)

# %%
#df_aux3['LOC_OF_OCCUR_DESC'].value_counts()

# %%
validos = ["M", "U", "F"]
df_aux3['SUSP_SEX'] = df_aux3['SUSP_SEX'].astype(str)

df_aux3['SUSP_SEX'] = df_aux3['SUSP_SEX'].apply(
    lambda x: x if x in validos else "U"
)
df_aux3['SUSP_SEX'] = df_aux3['SUSP_SEX'].replace("nan", "U")

# %%
df_aux3.SUSP_SEX.value_counts()
# Out:
# SUSP_SEX
# U    3224
# M    1987
# F     728
# Name: count, dtype: int64

# %%
df_aux3['PREM_TYP_DESC'] = (
    df_aux3['PREM_TYP_DESC']
    .cat.add_categories(['UNKNOWN'])
    .fillna('UNKNOWN')
)

# %%
df_aux3['PREM_TYP_DESC'].value_counts()
# Out:
# PREM_TYP_DESC
# RESIDENCE - APT. HOUSE        2091
# RESIDENCE-HOUSE                986
# STREET                         904
# RESIDENCE - PUBLIC HOUSING     320
# CHAIN STORE                    218
#                               ...
# TELECOMM. STORE                  1
# TAXI/LIVERY (UNLICENSED)         1
# TUNNEL                           1
# VARIETY STORE                    1
# VIDEO STORE                      1
# Name: count, Length: 72, dtype: int64

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 69              60   01/01/2025     13:40:00   01/01/2026     13:45:00
# 70             101   12/30/2025     10:34:00   12/30/2025     21:00:00
# 95              63   12/31/2025     21:00:00   12/31/2025     21:30:00
# 99              60   11/20/2025     20:00:00   11/20/2025     21:00:00
# 108             60   12/28/2025     19:09:00   12/28/2025     19:10:00
# ...            ...          ...          ...          ...          ...
# 132937          47   12/31/2025     12:19:00   12/31/2025     12:25:00
# 133020          45   12/20/2025     08:00:00   01/24/2026     09:00:00
# 133036          47   12/30/2025     13:00:00   01/06/2026     15:00:00
# 133089          52   12/01/2025     22:35:00          NaN          NaN
# 133090          47   12/22/2025     14:00:00   01/22/2026     12:30:00
#
#        CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC      RPT_DT  \
# 69            COMPLETED    VIOLATION          GROCERY/BODEGA  01/01/2026
# 70            COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE  01/03/2026
# 95            COMPLETED    VIOLATION         RESIDENCE-HOUSE  01/01/2026
# 99            COMPLETED       FELONY  RESIDENCE - APT. HOUSE  02/11/2026
# 108           COMPLETED       FELONY               FAST FOOD  01/02/2026
# ...                 ...          ...                     ...         ...
# 132937        COMPLETED       FELONY                  STREET  01/01/2026
# 133020        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE  03/14/2026
# 133036        COMPLETED  MISDEMEANOR        STORAGE FACILITY  01/06/2026
# 133089        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE  02/04/2026
# 133090        COMPLETED       FELONY     COMMERCIAL BUILDING  01/22/2026
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036        UNKNOWN         UNKNOWN        U           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  X_COORD_CD  Y_COORD_CD   Latitude  \
# 69      ASIAN / PACIFIC ISLANDER       M      989419      149229  40,576284
# 70                         BLACK       M     1051811      156239   40,59527
# 95                         BLACK       F     1007120      166200  40,622837
# 99                         BLACK       M      988814      149158  40,576087
# 108     ASIAN / PACIFIC ISLANDER       M      985092      148865  40,575285
# ...                          ...     ...         ...         ...        ...
# 132937                     BLACK       F     1024351      260917   40,88275
# 133020            WHITE HISPANIC       F     1032451      257889  40,874398
# 133036                     WHITE       M     1028591      258644   40,87649
# 133089                   UNKNOWN       M     1018488      258415  40,875908
# 133090                   UNKNOWN       D     1021675      265917  40,896484
#
#          Longitude                  Lat_Lon      New Georeferenced Column  \
# 69      -73,981392  (40.576284, -73.981392)  POINT (-73.981392 40.576284)
# 70      -73,756726   (40.59527, -73.756726)   POINT (-73.756726 40.59527)
# 95      -73,917614  (40.622837, -73.917614)  POINT (-73.917614 40.622837)
# 99      -73,983569  (40.576087, -73.983569)  POINT (-73.983569 40.576087)
# 108     -73,996969  (40.575285, -73.996969)  POINT (-73.996969 40.575285)
# ...            ...                      ...                           ...
# 132937   -73,85498    (40.88275, -73.85498)    POINT (-73.85498 40.88275)
# 133020  -73,825707  (40.874398, -73.825707)  POINT (-73.825707 40.874398)
# 133036  -73,839661   (40.87649, -73.839661)   POINT (-73.839661 40.87649)
# 133089  -73,876194  (40.875908, -73.876194)  POINT (-73.876194 40.875908)
# 133090   -73,86463   (40.896484, -73.86463)   POINT (-73.86463 40.896484)
#
#         IN_PARK  IN_TRANSIT  IN_HOUSING
# 69            0           0           0
# 70            0           0           0
# 95            0           0           0
# 99            0           0           0
# 108           0           0           0
# ...         ...         ...         ...
# 132937        0           0           0
# 133020        0           0           0
# 133036        0           0           0
# 133089        0           0           0
# 133090        0           0           0
#
# [5939 rows x 24 columns]

# %% [markdown]
# borro las columnas geofraficas

# %%
df_aux3 = df_aux3.drop(columns=["Lat_Lon","New Georeferenced Column","X_COORD_CD","Y_COORD_CD","Latitude","Longitude"])

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 69              60   01/01/2025     13:40:00   01/01/2026     13:45:00
# 70             101   12/30/2025     10:34:00   12/30/2025     21:00:00
# 95              63   12/31/2025     21:00:00   12/31/2025     21:30:00
# 99              60   11/20/2025     20:00:00   11/20/2025     21:00:00
# 108             60   12/28/2025     19:09:00   12/28/2025     19:10:00
# ...            ...          ...          ...          ...          ...
# 132937          47   12/31/2025     12:19:00   12/31/2025     12:25:00
# 133020          45   12/20/2025     08:00:00   01/24/2026     09:00:00
# 133036          47   12/30/2025     13:00:00   01/06/2026     15:00:00
# 133089          52   12/01/2025     22:35:00          NaN          NaN
# 133090          47   12/22/2025     14:00:00   01/22/2026     12:30:00
#
#        CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC      RPT_DT  \
# 69            COMPLETED    VIOLATION          GROCERY/BODEGA  01/01/2026
# 70            COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE  01/03/2026
# 95            COMPLETED    VIOLATION         RESIDENCE-HOUSE  01/01/2026
# 99            COMPLETED       FELONY  RESIDENCE - APT. HOUSE  02/11/2026
# 108           COMPLETED       FELONY               FAST FOOD  01/02/2026
# ...                 ...          ...                     ...         ...
# 132937        COMPLETED       FELONY                  STREET  01/01/2026
# 133020        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE  03/14/2026
# 133036        COMPLETED  MISDEMEANOR        STORAGE FACILITY  01/06/2026
# 133089        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE  02/04/2026
# 133090        COMPLETED       FELONY     COMMERCIAL BUILDING  01/22/2026
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036        UNKNOWN         UNKNOWN        U           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  IN_PARK  IN_TRANSIT  IN_HOUSING
# 69      ASIAN / PACIFIC ISLANDER       M        0           0           0
# 70                         BLACK       M        0           0           0
# 95                         BLACK       F        0           0           0
# 99                         BLACK       M        0           0           0
# 108     ASIAN / PACIFIC ISLANDER       M        0           0           0
# ...                          ...     ...      ...         ...         ...
# 132937                     BLACK       F        0           0           0
# 133020            WHITE HISPANIC       F        0           0           0
# 133036                     WHITE       M        0           0           0
# 133089                   UNKNOWN       M        0           0           0
# 133090                   UNKNOWN       D        0           0           0
#
# [5939 rows x 18 columns]

# %%
df_aux3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 69 to 133090
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ADDR_PCT_CD       5939 non-null   category
#  1   CMPLNT_FR_DT      5939 non-null   object
#  2   CMPLNT_FR_TM      5939 non-null   object
#  3   CMPLNT_TO_DT      5579 non-null   object
#  4   CMPLNT_TO_TM      5575 non-null   object
#  5   CRM_ATPT_CPTD_CD  5939 non-null   category
#  6   LAW_CAT_CD        5939 non-null   category
#  7   PREM_TYP_DESC     5939 non-null   category
#  8   RPT_DT            5939 non-null   object
#  9   SUSP_AGE_GROUP    5939 non-null   object
#  10  SUSP_RACE         5939 non-null   object
#  11  SUSP_SEX          5939 non-null   object
#  12  VIC_AGE_GROUP     5939 non-null   object
#  13  VIC_RACE          5939 non-null   object
#  14  VIC_SEX           5939 non-null   category
#  15  IN_PARK           5939 non-null   int64
#  16  IN_TRANSIT        5939 non-null   int64
#  17  IN_HOUSING        5939 non-null   int64
# dtypes: category(5), int64(3), object(10)
# memory usage: 684.3+ KB

# %%
df_aux3['CMPLNT_FR_DT'] = pd.to_datetime(df_aux3['CMPLNT_FR_DT'], errors='coerce')
df_aux3['CMPLNT_TO_DT'] = pd.to_datetime(df_aux3['CMPLNT_TO_DT'], errors='coerce')
df_aux3['RPT_DT'] = pd.to_datetime(df_aux3['RPT_DT'], errors='coerce')


df_aux3['CMPLNT_FR_TM'] = pd.to_timedelta(df_aux3['CMPLNT_FR_TM'])
df_aux3['CMPLNT_TO_TM'] = pd.to_timedelta(df_aux3['CMPLNT_TO_TM'])
df_aux3['DT_FR'] = df_aux3['CMPLNT_FR_DT'] + df_aux3['CMPLNT_FR_TM']
df_aux3['DT_TO'] = df_aux3['CMPLNT_TO_DT'] + df_aux3['CMPLNT_TO_TM']

# %%
df_aux3['HOUR_FR'] = df_aux3['DT_FR'].dt.hour.astype('Int8')
df_aux3['DAY_OF_WEEK_FR'] = df_aux3['DT_FR'].dt.dayofweek.astype('Int8')
df_aux3['MONTH_FR'] = df_aux3['DT_FR'].dt.month.astype('Int8')
df_aux3['IS_WEEKEND'] = df_aux3['DAY_OF_WEEK_FR'].isin([5,6]).astype('int8')

df_aux3['REPORT_DELAY_DAYS'] = (
    df_aux3['RPT_DT'] - df_aux3['DT_FR']
).dt.days


dur = (
    (df_aux3['DT_TO'] - df_aux3['DT_FR'])
    .dt.total_seconds() / (3600 * 24)
)

df_aux3['DURATION_DAYS'] = (
    dur.fillna(-1)
       .astype('int16')
)

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CMPLNT_FR_DT    CMPLNT_FR_TM CMPLNT_TO_DT    CMPLNT_TO_TM  \
# 69              60   2025-01-01 0 days 13:40:00   2026-01-01 0 days 13:45:00
# 70             101   2025-12-30 0 days 10:34:00   2025-12-30 0 days 21:00:00
# 95              63   2025-12-31 0 days 21:00:00   2025-12-31 0 days 21:30:00
# 99              60   2025-11-20 0 days 20:00:00   2025-11-20 0 days 21:00:00
# 108             60   2025-12-28 0 days 19:09:00   2025-12-28 0 days 19:10:00
# ...            ...          ...             ...          ...             ...
# 132937          47   2025-12-31 0 days 12:19:00   2025-12-31 0 days 12:25:00
# 133020          45   2025-12-20 0 days 08:00:00   2026-01-24 0 days 09:00:00
# 133036          47   2025-12-30 0 days 13:00:00   2026-01-06 0 days 15:00:00
# 133089          52   2025-12-01 0 days 22:35:00          NaT             NaT
# 133090          47   2025-12-22 0 days 14:00:00   2026-01-22 0 days 12:30:00
#
#        CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC     RPT_DT  \
# 69            COMPLETED    VIOLATION          GROCERY/BODEGA 2026-01-01
# 70            COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE 2026-01-03
# 95            COMPLETED    VIOLATION         RESIDENCE-HOUSE 2026-01-01
# 99            COMPLETED       FELONY  RESIDENCE - APT. HOUSE 2026-02-11
# 108           COMPLETED       FELONY               FAST FOOD 2026-01-02
# ...                 ...          ...                     ...        ...
# 132937        COMPLETED       FELONY                  STREET 2026-01-01
# 133020        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE 2026-03-14
# 133036        COMPLETED  MISDEMEANOR        STORAGE FACILITY 2026-01-06
# 133089        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE 2026-02-04
# 133090        COMPLETED       FELONY     COMMERCIAL BUILDING 2026-01-22
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036        UNKNOWN         UNKNOWN        U           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  IN_PARK  IN_TRANSIT  IN_HOUSING  \
# 69      ASIAN / PACIFIC ISLANDER       M        0           0           0
# 70                         BLACK       M        0           0           0
# 95                         BLACK       F        0           0           0
# 99                         BLACK       M        0           0           0
# 108     ASIAN / PACIFIC ISLANDER       M        0           0           0
# ...                          ...     ...      ...         ...         ...
# 132937                     BLACK       F        0           0           0
# 133020            WHITE HISPANIC       F        0           0           0
# 133036                     WHITE       M        0           0           0
# 133089                   UNKNOWN       M        0           0           0
# 133090                   UNKNOWN       D        0           0           0
#
#                      DT_FR               DT_TO  HOUR_FR  DAY_OF_WEEK_FR  \
# 69     2025-01-01 13:40:00 2026-01-01 13:45:00       13               2
# 70     2025-12-30 10:34:00 2025-12-30 21:00:00       10               1
# 95     2025-12-31 21:00:00 2025-12-31 21:30:00       21               2
# 99     2025-11-20 20:00:00 2025-11-20 21:00:00       20               3
# 108    2025-12-28 19:09:00 2025-12-28 19:10:00       19               6
# ...                    ...                 ...      ...             ...
# 132937 2025-12-31 12:19:00 2025-12-31 12:25:00       12               2
# 133020 2025-12-20 08:00:00 2026-01-24 09:00:00        8               5
# 133036 2025-12-30 13:00:00 2026-01-06 15:00:00       13               1
# 133089 2025-12-01 22:35:00                 NaT       22               0
# 133090 2025-12-22 14:00:00 2026-01-22 12:30:00       14               0
#
#         MONTH_FR  IS_WEEKEND  REPORT_DELAY_DAYS  DURATION_DAYS
# 69             1           0                364            365
# 70            12           0                  3              0
# 95            12           0                  0              0
# 99            11           0                 82              0
# 108           12           1                  4              0
# ...          ...         ...                ...            ...
# 132937        12           0                  0              0
# 133020        12           1                 83             35
# 133036        12           0                  6              7
# 133089        12           0                 64             -1
# 133090        12           0                 30             30
#
# [5939 rows x 26 columns]

# %%
df_aux3 = df_aux3.drop(columns=[ "CMPLNT_FR_DT","CMPLNT_FR_TM","CMPLNT_TO_DT","CMPLNT_TO_TM",	"DT_FR","DT_TO","RPT_DT" ])

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC  \
# 69              60        COMPLETED    VIOLATION          GROCERY/BODEGA
# 70             101        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE
# 95              63        COMPLETED    VIOLATION         RESIDENCE-HOUSE
# 99              60        COMPLETED       FELONY  RESIDENCE - APT. HOUSE
# 108             60        COMPLETED       FELONY               FAST FOOD
# ...            ...              ...          ...                     ...
# 132937          47        COMPLETED       FELONY                  STREET
# 133020          45        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE
# 133036          47        COMPLETED  MISDEMEANOR        STORAGE FACILITY
# 133089          52        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE
# 133090          47        COMPLETED       FELONY     COMMERCIAL BUILDING
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036        UNKNOWN         UNKNOWN        U           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  IN_PARK  IN_TRANSIT  IN_HOUSING  \
# 69      ASIAN / PACIFIC ISLANDER       M        0           0           0
# 70                         BLACK       M        0           0           0
# 95                         BLACK       F        0           0           0
# 99                         BLACK       M        0           0           0
# 108     ASIAN / PACIFIC ISLANDER       M        0           0           0
# ...                          ...     ...      ...         ...         ...
# 132937                     BLACK       F        0           0           0
# 133020            WHITE HISPANIC       F        0           0           0
# 133036                     WHITE       M        0           0           0
# 133089                   UNKNOWN       M        0           0           0
# 133090                   UNKNOWN       D        0           0           0
#
#         HOUR_FR  DAY_OF_WEEK_FR  MONTH_FR  IS_WEEKEND  REPORT_DELAY_DAYS  \
# 69           13               2         1           0                364
# 70           10               1        12           0                  3
# 95           21               2        12           0                  0
# 99           20               3        11           0                 82
# 108          19               6        12           1                  4
# ...         ...             ...       ...         ...                ...
# 132937       12               2        12           0                  0
# 133020        8               5        12           1                 83
# 133036       13               1        12           0                  6
# 133089       22               0        12           0                 64
# 133090       14               0        12           0                 30
#
#         DURATION_DAYS
# 69                365
# 70                  0
# 95                  0
# 99                  0
# 108                 0
# ...               ...
# 132937              0
# 133020             35
# 133036              7
# 133089             -1
# 133090             30
#
# [5939 rows x 19 columns]

# %% [markdown]
# Esto lo sacamos de analizar los outliers en duration_days

# %%
def duration_state(x):
    if pd.isna(x) | x<0 :
        return 'UNKNOWN'
    elif  0<=  x < 1:
        return 'SAME_DAY'
    elif x <= 7:
        return 'SHORT'
    elif x <= 30:
        return 'MEDIUM'
    elif x <= 180:
        return 'LONG'
    else:
        return 'VERY_LONG'

df_aux3['DURATION_STATE'] = df_aux3['DURATION_DAYS'].apply(duration_state)
df_aux3['REPORT_DELAY_STATE'] = df_aux3['REPORT_DELAY_DAYS'].apply(duration_state)

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC  \
# 69              60        COMPLETED    VIOLATION          GROCERY/BODEGA
# 70             101        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE
# 95              63        COMPLETED    VIOLATION         RESIDENCE-HOUSE
# 99              60        COMPLETED       FELONY  RESIDENCE - APT. HOUSE
# 108             60        COMPLETED       FELONY               FAST FOOD
# ...            ...              ...          ...                     ...
# 132937          47        COMPLETED       FELONY                  STREET
# 133020          45        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE
# 133036          47        COMPLETED  MISDEMEANOR        STORAGE FACILITY
# 133089          52        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE
# 133090          47        COMPLETED       FELONY     COMMERCIAL BUILDING
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036        UNKNOWN         UNKNOWN        U           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  IN_PARK  IN_TRANSIT  IN_HOUSING  \
# 69      ASIAN / PACIFIC ISLANDER       M        0           0           0
# 70                         BLACK       M        0           0           0
# 95                         BLACK       F        0           0           0
# 99                         BLACK       M        0           0           0
# 108     ASIAN / PACIFIC ISLANDER       M        0           0           0
# ...                          ...     ...      ...         ...         ...
# 132937                     BLACK       F        0           0           0
# 133020            WHITE HISPANIC       F        0           0           0
# 133036                     WHITE       M        0           0           0
# 133089                   UNKNOWN       M        0           0           0
# 133090                   UNKNOWN       D        0           0           0
#
#         HOUR_FR  DAY_OF_WEEK_FR  MONTH_FR  IS_WEEKEND  REPORT_DELAY_DAYS  \
# 69           13               2         1           0                364
# 70           10               1        12           0                  3
# 95           21               2        12           0                  0
# 99           20               3        11           0                 82
# 108          19               6        12           1                  4
# ...         ...             ...       ...         ...                ...
# 132937       12               2        12           0                  0
# 133020        8               5        12           1                 83
# 133036       13               1        12           0                  6
# 133089       22               0        12           0                 64
# 133090       14               0        12           0                 30
#
#         DURATION_DAYS DURATION_STATE REPORT_DELAY_STATE
# 69                365      VERY_LONG          VERY_LONG
# 70                  0       SAME_DAY              SHORT
# 95                  0       SAME_DAY           SAME_DAY
# 99                  0       SAME_DAY               LONG
# 108                 0       SAME_DAY              SHORT
# ...               ...            ...                ...
# 132937              0       SAME_DAY           SAME_DAY
# 133020             35           LONG               LONG
# 133036              7          SHORT              SHORT
# 133089             -1        UNKNOWN               LONG
# 133090             30         MEDIUM             MEDIUM
#
# [5939 rows x 21 columns]

# %%
df_aux3.DURATION_STATE.value_counts()
# Out:
# DURATION_STATE
# SAME_DAY     2566
# LONG         1163
# MEDIUM        701
# VERY_LONG     591
# SHORT         552
# UNKNOWN       366
# Name: count, dtype: int64

# %%
df_aux3.REPORT_DELAY_STATE.value_counts()
# Out:
# REPORT_DELAY_STATE
# LONG         2908
# VERY_LONG    1267
# MEDIUM       1145
# SHORT         481
# SAME_DAY      138
# Name: count, dtype: int64

# %%
df_aux3 = df_aux3.drop(columns=[ "REPORT_DELAY_DAYS","DURATION_DAYS"])

# %%
df_aux3
# Out:
#        ADDR_PCT_CD CRM_ATPT_CPTD_CD   LAW_CAT_CD           PREM_TYP_DESC  \
# 69              60        COMPLETED    VIOLATION          GROCERY/BODEGA
# 70             101        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE
# 95              63        COMPLETED    VIOLATION         RESIDENCE-HOUSE
# 99              60        COMPLETED       FELONY  RESIDENCE - APT. HOUSE
# 108             60        COMPLETED       FELONY               FAST FOOD
# ...            ...              ...          ...                     ...
# 132937          47        COMPLETED       FELONY                  STREET
# 133020          45        COMPLETED    VIOLATION  RESIDENCE - APT. HOUSE
# 133036          47        COMPLETED  MISDEMEANOR        STORAGE FACILITY
# 133089          52        COMPLETED  MISDEMEANOR  RESIDENCE - APT. HOUSE
# 133090          47        COMPLETED       FELONY     COMMERCIAL BUILDING
#
#        SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX VIC_AGE_GROUP  \
# 69            UNKNOWN           BLACK        M         25-44
# 70            UNKNOWN         UNKNOWN        U         25-44
# 95            UNKNOWN         UNKNOWN        U         25-44
# 99              45-64           BLACK        F         45-64
# 108           UNKNOWN           BLACK        M         18-24
# ...               ...             ...      ...           ...
# 132937        UNKNOWN         UNKNOWN        U         25-44
# 133020        UNKNOWN  BLACK HISPANIC        U         45-64
# 133036        UNKNOWN         UNKNOWN        U           65+
# 133089          25-44         UNKNOWN        M       UNKNOWN
# 133090        UNKNOWN         UNKNOWN        U       UNKNOWN
#
#                         VIC_RACE VIC_SEX  IN_PARK  IN_TRANSIT  IN_HOUSING  \
# 69      ASIAN / PACIFIC ISLANDER       M        0           0           0
# 70                         BLACK       M        0           0           0
# 95                         BLACK       F        0           0           0
# 99                         BLACK       M        0           0           0
# 108     ASIAN / PACIFIC ISLANDER       M        0           0           0
# ...                          ...     ...      ...         ...         ...
# 132937                     BLACK       F        0           0           0
# 133020            WHITE HISPANIC       F        0           0           0
# 133036                     WHITE       M        0           0           0
# 133089                   UNKNOWN       M        0           0           0
# 133090                   UNKNOWN       D        0           0           0
#
#         HOUR_FR  DAY_OF_WEEK_FR  MONTH_FR  IS_WEEKEND DURATION_STATE  \
# 69           13               2         1           0      VERY_LONG
# 70           10               1        12           0       SAME_DAY
# 95           21               2        12           0       SAME_DAY
# 99           20               3        11           0       SAME_DAY
# 108          19               6        12           1       SAME_DAY
# ...         ...             ...       ...         ...            ...
# 132937       12               2        12           0       SAME_DAY
# 133020        8               5        12           1           LONG
# 133036       13               1        12           0          SHORT
# 133089       22               0        12           0        UNKNOWN
# 133090       14               0        12           0         MEDIUM
#
#        REPORT_DELAY_STATE
# 69              VERY_LONG
# 70                  SHORT
# 95               SAME_DAY
# 99                   LONG
# 108                 SHORT
# ...                   ...
# 132937           SAME_DAY
# 133020               LONG
# 133036              SHORT
# 133089               LONG
# 133090             MEDIUM
#
# [5939 rows x 19 columns]

# %%
def franja_horaria(hora):
    if 0 <= hora <= 5:
        return 'Early morning'
    elif 6 <= hora <= 11:
        return 'Morning'
    elif 12 <= hora <= 17:
        return 'Afternoon'
    else:
        return 'Night'

df_aux3['TIME_PERIOD'] = df_aux3['HOUR_FR'].apply(franja_horaria)

# %%
def estacion(mes):
    if mes in [12, 1, 2]:
        return 'Summer'
    elif mes in [3, 4, 5]:
        return 'Autumn'
    elif mes in [6, 7, 8]:
        return 'Winter'
    else:
        return 'Spring'

df_aux3['SEASON'] = df_aux3['MONTH_FR'].apply(estacion)

# %%
df_aux3 = df_aux3.drop(columns=['HOUR_FR','MONTH_FR'])

# %%
df_aux3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 69 to 133090
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ADDR_PCT_CD         5939 non-null   category
#  1   CRM_ATPT_CPTD_CD    5939 non-null   category
#  2   LAW_CAT_CD          5939 non-null   category
#  3   PREM_TYP_DESC       5939 non-null   category
#  4   SUSP_AGE_GROUP      5939 non-null   object
#  5   SUSP_RACE           5939 non-null   object
#  6   SUSP_SEX            5939 non-null   object
#  7   VIC_AGE_GROUP       5939 non-null   object
#  8   VIC_RACE            5939 non-null   object
#  9   VIC_SEX             5939 non-null   category
#  10  IN_PARK             5939 non-null   int64
#  11  IN_TRANSIT          5939 non-null   int64
#  12  IN_HOUSING          5939 non-null   int64
#  13  DAY_OF_WEEK_FR      5939 non-null   Int8
#  14  IS_WEEKEND          5939 non-null   int8
#  15  DURATION_STATE      5939 non-null   object
#  16  REPORT_DELAY_STATE  5939 non-null   object
#  17  TIME_PERIOD         5939 non-null   object
#  18  SEASON              5939 non-null   object
# dtypes: Int8(1), category(5), int64(3), int8(1), object(9)
# memory usage: 655.3+ KB

# %%
delito_cat_nom = [
    "SUSP_AGE_GROUP",
    "SUSP_RACE",
    "SUSP_SEX",
   "VIC_AGE_GROUP",
   "VIC_RACE",
  "DURATION_STATE",
  "REPORT_DELAY_STATE",
  "SEASON",
  "TIME_PERIOD"
 ]#delito_cat_num= ['ADDR_PCT_CD', 'ADDR_PCT_CD','sibsp', 'parch']
dtype_map ={col: 'category' for col in delito_cat_nom}

df_aux3 = df_aux3.astype(dtype_map)

# %%
df_aux3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 69 to 133090
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ADDR_PCT_CD         5939 non-null   category
#  1   CRM_ATPT_CPTD_CD    5939 non-null   category
#  2   LAW_CAT_CD          5939 non-null   category
#  3   PREM_TYP_DESC       5939 non-null   category
#  4   SUSP_AGE_GROUP      5939 non-null   category
#  5   SUSP_RACE           5939 non-null   category
#  6   SUSP_SEX            5939 non-null   category
#  7   VIC_AGE_GROUP       5939 non-null   category
#  8   VIC_RACE            5939 non-null   category
#  9   VIC_SEX             5939 non-null   category
#  10  IN_PARK             5939 non-null   int64
#  11  IN_TRANSIT          5939 non-null   int64
#  12  IN_HOUSING          5939 non-null   int64
#  13  DAY_OF_WEEK_FR      5939 non-null   Int8
#  14  IS_WEEKEND          5939 non-null   int8
#  15  DURATION_STATE      5939 non-null   category
#  16  REPORT_DELAY_STATE  5939 non-null   category
#  17  TIME_PERIOD         5939 non-null   category
#  18  SEASON              5939 non-null   category
# dtypes: Int8(1), category(14), int64(3), int8(1)
# memory usage: 292.0 KB

# %% [markdown]
# el split lo hago aca

# %%
X = df_aux3.drop(columns=["LAW_CAT_CD"])
y = df_aux3["LAW_CAT_CD"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20, # 80% entrenamiento, 20% para test (también se suele usar 70/30 o 75/25)
    random_state=42, # semilla para reproducibilidad (para que el split se haga siempre igual)
    shuffle = True, # mezclar antes de hacer el split (por defecto es True)
    stratify = None # ya veremos qué hace!
)

print("Verificamos el split 80-20")
print(f"Dataset completo : {len(X)} filas")
print(f"X_train            : {X_train.shape[0]} filas, {X_train.shape[1]} columnas  ({X_train.shape[0]/len(X):.0%})")
print(f"X_test             : {X_test.shape[0]} filas, {X_test.shape[1]} columnas   ({X_test.shape[0]/len(X):.0%})")
print(f"y_train            : {(pd.DataFrame(y_train).shape[0])} filas, {pd.DataFrame(y_train).shape[1]} columna(s)  ({pd.DataFrame(y_train).shape[0]/len(y):.0%})")
print(f"y_test             : {pd.DataFrame(y_test).shape[0]} filas, {pd.DataFrame(y_test).shape[1]} columna(s)   ({pd.DataFrame(y_test).shape[0]/len(y):.0%})")
# Out:
# Verificamos el split 80-20
# Dataset completo : 5939 filas
# X_train            : 4751 filas, 18 columnas  (80%)
# X_test             : 1188 filas, 18 columnas   (20%)
# y_train            : 4751 filas, 1 columna(s)  (80%)
# y_test             : 1188 filas, 1 columna(s)   (20%)

# %% [markdown]
# # **Punto 5**
#
# **Feature engineering**
#
# * Crear nuevos features en caso de ser necesario. Justificar.
# * Aplicar técnicas de conversión de variables: codificación, discretización.
# * Analizar el balance/desbalance de clases (en el caso que se trate de un problema de clasificación).
# * Proponer y aplicar mecanismos de balance en caso de ser necesario y justificar la selección.

# %%
def codificar_x(X):

  # Variables categóricas ordinales
  X['DURATION_STATE'] = X['DURATION_STATE'].map({'UNKNOWN': 0, 'SAME_DAY': 1, 'SHORT':2, 'MEDIUM':3, 'LONG':4, 'VERY_LONG':5 }).astype(int)
  X['REPORT_DELAY_STATE'] = X['REPORT_DELAY_STATE'].map({'SAME_DAY': 1, 'SHORT':2, 'MEDIUM':3, 'LONG':4, 'VERY_LONG':5 }).astype(int)

  # One hot encoding
  X_ = pd.concat([X, pd.get_dummies(X['SUSP_SEX'], prefix='SUSP_SEX').drop(columns='SUSP_SEX_U')], axis=1)
  X = pd.concat([X, pd.get_dummies(X['VIC_SEX'], prefix='VIC_SEX').drop(columns=['VIC_SEX_D','VIC_SEX_E','VIC_SEX_L'])], axis=1)

  X = pd.concat([X, pd.get_dummies(X['SUSP_RACE'], prefix='SUSP_RACE').drop(columns='SUSP_RACE_UNKNOWN')], axis=1)
  X = pd.concat([X, pd.get_dummies(X['VIC_RACE'], prefix='VIC_RACE').drop(columns='VIC_RACE_UNKNOWN')], axis=1)

  X = pd.concat([X, pd.get_dummies(X['SUSP_AGE_GROUP'], prefix='SUSP_AGE').drop(columns='SUSP_AGE_UNKNOWN')], axis=1)
  X = pd.concat([X, pd.get_dummies(X['VIC_AGE_GROUP'], prefix='VIC_AGE').drop(columns='VIC_AGE_UNKNOWN')], axis=1)


  X = X.drop(columns=['SUSP_SEX','VIC_SEX','SUSP_RACE','VIC_RACE','VIC_AGE_GROUP','SUSP_AGE_GROUP'])

  # Tiempos
  X = pd.get_dummies(
      X,
      columns=['TIME_PERIOD'],
      dtype=int
  )

  X = pd.get_dummies(
      X,
      columns=['SEASON'],
      dtype=int
  )

  # Completed / no completed a Binario
  X['CRM_ATPT_CPTD_CD'] = (X['CRM_ATPT_CPTD_CD']).map({'COMPLETED': 1}).fillna(0).astype(int)

  ## Frequency encoding
  # ADDR_PCT_CD
  freq = X['ADDR_PCT_CD'].value_counts(normalize=True)
  X['ADDR_PCT_CD_FREQ'] = X['ADDR_PCT_CD'].map(freq)
  X = X.drop(columns=['ADDR_PCT_CD'])

  # PREM_TYP_DESC
  freq = X['PREM_TYP_DESC'].value_counts(normalize=True)
  X['PREM_TYP_DESC_FREQ'] = X['PREM_TYP_DESC'].map(freq)
  X = X.drop(columns=['PREM_TYP_DESC'])

  return X

# %%
X_train = codificar_x(X_train)
X_test = codificar_x(X_test)

# %% [markdown]
# # **En este punto están todas las variables del dataset de entrenamiento codificadas**

# %%
X_train.dtypes
# Out:
# CRM_ATPT_CPTD_CD                              int64
# IN_PARK                                       int64
# IN_TRANSIT                                    int64
# IN_HOUSING                                    int64
# DAY_OF_WEEK_FR                                 Int8
# IS_WEEKEND                                     int8
# DURATION_STATE                                int64
# REPORT_DELAY_STATE                            int64
# VIC_SEX_F                                      bool
# VIC_SEX_M                                      bool
# SUSP_RACE_AMERICAN INDIAN/ALASKAN NATIVE       bool
# SUSP_RACE_ASIAN / PACIFIC ISLANDER             bool
# SUSP_RACE_BLACK                                bool
# SUSP_RACE_BLACK HISPANIC                       bool
# SUSP_RACE_WHITE                                bool
# SUSP_RACE_WHITE HISPANIC                       bool
# VIC_RACE_AMERICAN INDIAN/ALASKAN NATIVE        bool
# VIC_RACE_ASIAN / PACIFIC ISLANDER              bool
# VIC_RACE_BLACK                                 bool
# VIC_RACE_BLACK HISPANIC                        bool
# VIC_RACE_WHITE                                 bool
# VIC_RACE_WHITE HISPANIC                        bool
# SUSP_AGE_18-24                                 bool
# SUSP_AGE_25-44                                 bool
# SUSP_AGE_45-64                                 bool
# SUSP_AGE_65+                                   bool
# SUSP_AGE_<18                                   bool
# VIC_AGE_18-24                                  bool
# VIC_AGE_25-44                                  bool
# VIC_AGE_45-64                                  bool
# VIC_AGE_65+                                    bool
# VIC_AGE_<18                                    bool
# TIME_PERIOD_Afternoon                         int64
# TIME_PERIOD_Early morning                     int64
# TIME_PERIOD_Morning                           int64
# TIME_PERIOD_Night                             int64
# SEASON_Autumn                                 int64
# SEASON_Spring                                 int64
# SEASON_Summer                                 int64
# SEASON_Winter                                 int64
# ADDR_PCT_CD_FREQ                            float64
# PREM_TYP_DESC_FREQ                          float64
# dtype: object

# %% [markdown]
# # **VARIABLE TARGET**
#
# # **Podemos convertir dato categórico del nivel del delito a número, ya que es categórico ordinal.**

# %%
y_train = y_train.map({'VIOLATION': 1, 'MISDEMEANOR': 2, 'FELONY': 3})
y_test = y_test.map({'VIOLATION': 1, 'MISDEMEANOR': 2, 'FELONY': 3})

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

y_train.value_counts().sort_index().plot(
    kind='bar',
    ax=axes[0],
    title='y_train'
)

y_test.value_counts().sort_index().plot(
    kind='bar',
    ax=axes[1],
    title='y_test'
)

axes[0].set_xlabel('Clase')
axes[0].set_ylabel('Cantidad')

axes[1].set_xlabel('Clase')
axes[1].set_ylabel('Cantidad')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Vamos a tener que aplicar técnicas de balanceo por la diferencia en cantidad de datos en las posibles variables target**
#
#
# Como vemos abajo la clase 1 (violation) tiene sólo un 11% de las muestras

# %%
(y_train.value_counts(normalize=True) * 100).round(2)
# Out:
# LAW_CAT_CD
# 2    48.14
# 3    40.81
# 1    11.05
# Name: proportion, dtype: float64

# %% [markdown]
# Vamos a tener que generar muestras de los datos 1 y 3 para balancear el dataset

# %% [markdown]
# Escalado y balanceo

# %%
import sys
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (0.14.2)
# Requirement already satisfied: numpy<3,>=1.25.2 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from imbalanced-learn) (2.2.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.6 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from imbalanced-learn) (0.1.6)
# Requirement already satisfied: joblib<2,>=1.2.0 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (from imbalanced-learn) (3.5.0)

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Escalado
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Oversampling
ros = RandomOverSampler(random_state=42)

X_train_bal, y_train_bal = ros.fit_resample(
    X_train_scaled,
    y_train
)

print("Antes:")
print(y_train.value_counts())

print("\nDespués:")
print(y_train_bal.value_counts())
# Out:
# Antes:
# LAW_CAT_CD
# 2    2287
# 3    1939
# 1     525
# Name: count, dtype: int64
#
# Después:
# LAW_CAT_CD
# 3    2287
# 2    2287
# 1    2287
# Name: count, dtype: int64

# %% [markdown]
# # **Punto 6**
#
# **Reducción de dimensionalidad**
#
# * Evaluar relaciones entre variables y realizar una selección de features con los mecanismos vistos en clase.
# * Implementar la técnica de extracción de features vista en clase (PCA). Evaluar ventajas y desventajas de la reducción

# %% [markdown]
# Hago correlación Kendall Tau porque tenemos varible Target categórica ordinal y queremos buscar la correlación con el resto de las columnas

# %%
# Unimos temporalmente X e y
df = X_train.copy()
df["target"] = y_train

# Correlación Kendall de todas las columnas contra el target
kendall_corr = df.corr(method="kendall")["target"].drop("target")

# Ordenamos por valor absoluto
kendall_corr = kendall_corr.reindex(
    kendall_corr.abs().sort_values(ascending=False).index
)

print(kendall_corr)
# Out:
# VIC_AGE_65+                                 0.110498
# SUSP_RACE_WHITE                            -0.093280
# VIC_RACE_BLACK                             -0.087694
# SUSP_RACE_BLACK                            -0.087484
# VIC_AGE_25-44                              -0.083180
# SUSP_AGE_45-64                             -0.076403
# DURATION_STATE                              0.075810
# SUSP_RACE_WHITE HISPANIC                   -0.066645
# VIC_SEX_F                                  -0.066590
# SUSP_AGE_25-44                             -0.065008
# CRM_ATPT_CPTD_CD                           -0.059980
# VIC_RACE_WHITE                              0.059949
# SUSP_AGE_65+                               -0.055062
# VIC_RACE_WHITE HISPANIC                    -0.054479
# TIME_PERIOD_Morning                         0.047734
# VIC_RACE_ASIAN / PACIFIC ISLANDER           0.044864
# TIME_PERIOD_Night                          -0.043638
# TIME_PERIOD_Early morning                   0.036943
# TIME_PERIOD_Afternoon                      -0.033871
# VIC_AGE_18-24                              -0.031515
# VIC_SEX_M                                   0.031191
# SEASON_Summer                              -0.027674
# SEASON_Spring                               0.026694
# IS_WEEKEND                                 -0.024835
# SUSP_RACE_BLACK HISPANIC                   -0.022505
# DAY_OF_WEEK_FR                             -0.021728
# PREM_TYP_DESC_FREQ                         -0.021402
# SUSP_AGE_<18                               -0.021221
# IN_TRANSIT                                 -0.017766
# SUSP_RACE_ASIAN / PACIFIC ISLANDER         -0.017215
# SUSP_AGE_18-24                              0.014804
# VIC_RACE_BLACK HISPANIC                    -0.014312
# SUSP_RACE_AMERICAN INDIAN/ALASKAN NATIVE   -0.013298
# ADDR_PCT_CD_FREQ                           -0.012493
# SEASON_Autumn                               0.012214
# IN_PARK                                     0.005205
# IN_HOUSING                                 -0.004943
# SEASON_Winter                              -0.003722
# VIC_RACE_AMERICAN INDIAN/ALASKAN NATIVE     0.003341
# VIC_AGE_<18                                -0.002606
# VIC_AGE_45-64                               0.001300
# REPORT_DELAY_STATE                          0.001115
# Name: target, dtype: float64

# %%
kendall_corr.abs().sort_values().plot(kind="barh", figsize=(8,12))
plt.xlabel("|Kendall Tau|")
plt.title("Correlación absoluta con la variable target")
plt.show()

# %% [markdown]
# Voy a descartar las columnas con menos de **0.02**

# %%
cols_correlacion_muy_debil = ['IN_TRANSIT' , 'SUSP_RACE_ASIAN / PACIFIC ISLANDER', 'SUSP_AGE_18-24','VIC_RACE_BLACK HISPANIC', 'SUSP_RACE_AMERICAN INDIAN/ALASKAN NATIVE', 'ADDR_PCT_CD_FREQ' ,
                              'SEASON_Autumn','IN_PARK','IN_HOUSING','SEASON_Winter' ,'VIC_RACE_AMERICAN INDIAN/ALASKAN NATIVE','VIC_AGE_<18','VIC_AGE_45-64','REPORT_DELAY_STATE']

X_train=X_train.drop(columns=cols_correlacion_muy_debil)
X_test=X_test.drop(columns=cols_correlacion_muy_debil)

# %% [markdown]
# Informción mutua

# %%
from sklearn.feature_selection import mutual_info_classif
import pandas as pd

# Calcular información mutua
mi_scores = mutual_info_classif(
    X_train,
    y_train,
    random_state=42
)

# Crear un DataFrame con los resultados
mi_df = pd.DataFrame({
    "Variable": X_train.columns,
    "Mutual Information": mi_scores
})

# Ordenar de mayor a menor
mi_df = mi_df.sort_values(
    by="Mutual Information",
    ascending=False
)

print(mi_df)
# Out:
#                              Variable  Mutual Information
# 3                      DURATION_STATE            0.025566
# 27                 PREM_TYP_DESC_FREQ            0.025152
# 19                      VIC_AGE_25-44            0.010892
# 6                     SUSP_RACE_BLACK            0.008885
# 16                       SUSP_AGE_65+            0.007772
# 20                        VIC_AGE_65+            0.006647
# 24                  TIME_PERIOD_Night            0.005089
# 11                     VIC_RACE_BLACK            0.004704
# 25                      SEASON_Spring            0.004496
# 22          TIME_PERIOD_Early morning            0.004335
# 10  VIC_RACE_ASIAN / PACIFIC ISLANDER            0.003909
# 12                     VIC_RACE_WHITE            0.003587
# 26                      SEASON_Summer            0.002913
# 4                           VIC_SEX_F            0.002804
# 15                     SUSP_AGE_45-64            0.001391
# 13            VIC_RACE_WHITE HISPANIC            0.000665
# 5                           VIC_SEX_M            0.000429
# 7            SUSP_RACE_BLACK HISPANIC            0.000082
# 0                    CRM_ATPT_CPTD_CD            0.000000
# 2                          IS_WEEKEND            0.000000
# 8                     SUSP_RACE_WHITE            0.000000
# 9            SUSP_RACE_WHITE HISPANIC            0.000000
# 1                      DAY_OF_WEEK_FR            0.000000
# 14                     SUSP_AGE_25-44            0.000000
# 18                      VIC_AGE_18-24            0.000000
# 17                       SUSP_AGE_<18            0.000000
# 23                TIME_PERIOD_Morning            0.000000
# 21              TIME_PERIOD_Afternoon            0.000000

# %%
mi_df = mi_df.sort_values("Mutual Information")

plt.figure(figsize=(8,10))
plt.barh(mi_df["Variable"], mi_df["Mutual Information"])
plt.xlabel("Mutual Information")
plt.title("Información mutua con la variable objetivo")
plt.show()

# %%
threshold = 0.001

selected_features = mi_df[
    mi_df["Mutual Information"] > threshold
]["Variable"]

print(f"Variables originales: {X_train.shape[1]}")

X_train = X_train[selected_features]
X_test = X_test[selected_features]


print(f"Variables seleccionadas: {len(selected_features)}")
# Out:
# Variables originales: 28
# Variables seleccionadas: 15

# %% [markdown]
# # **PCA**
#
# Las variables del dataset ya fueron normalizadas y escaladas en el punto 5

# %%
from sklearn.decomposition import PCA

pca = PCA()

X_train_pca = pca.fit_transform(X_train)


varianza = pca.explained_variance_ratio_
varianza_acumulada = np.cumsum(varianza)

print(varianza)
print(varianza_acumulada)

plt.figure(figsize=(8,5))
plt.plot(
    range(1, len(varianza_acumulada) + 1),
    varianza_acumulada,
    marker="o"
)
plt.xlabel("Número de componentes")
plt.ylabel("Varianza explicada acumulada")
plt.grid(True)
plt.show()
# Out:
# [0.55219715 0.08477587 0.06803276 0.05538539 0.04814461 0.04007534
#  0.033097   0.02816648 0.02466126 0.01817946 0.01451582 0.01333543
#  0.01304111 0.00373761 0.00265472]
# [0.55219715 0.63697301 0.70500577 0.76039117 0.80853577 0.84861111
#  0.88170811 0.90987459 0.93453584 0.9527153  0.96723113 0.98056656
#  0.99360767 0.99734528 1.        ]

# %%
# Me quedo con 10 componentes que acumulan aproximadamente un 95% de la varianza

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Escalamos nuevamente las 15 variables seleccionadas
# El scaler se ajusta solamente sobre el conjunto de entrenamiento
scaler_selected = StandardScaler()

X_train_selected_scaled = scaler_selected.fit_transform(X_train)
X_test_selected_scaled = scaler_selected.transform(X_test)

# Aplicamos PCA sobre las 15 variables seleccionadas
pca = PCA(n_components=10)

X_train_pca = pca.fit_transform(X_train_selected_scaled)
X_test_pca = pca.transform(X_test_selected_scaled)

print("Variables de entrada al PCA:", X_train.shape[1])
print("Componentes PCA:", X_train_pca.shape[1])
print(
    "Varianza explicada acumulada:",
    pca.explained_variance_ratio_.sum()
)
# Out:
# Variables de entrada al PCA: 15
# Componentes PCA: 10
# Varianza explicada acumulada: 0.8132457256766567

# %%
# !pip install pyarrow
import pyarrow
print(pyarrow.__version__)
# Out:
# Requirement already satisfied: pyarrow in /home/diego/anaconda3/envs/trabajo/lib/python3.10/site-packages (25.0.1)
# 25.0.1

# %%
import pandas as pd
pd.DataFrame(X_train_pca).to_csv("datos/X_train_pca.csv", index=False)
pd.DataFrame(X_test_pca).to_csv("datos/X_test_pca.csv", index=False)

y_train.to_frame().to_csv("datos/y_train.csv", index=False)
y_test.to_frame().to_csv("datos/y_test.csv", index=False)

pd.DataFrame(X_train).to_csv("datos/X_train.csv", index=False)
pd.DataFrame(X_test).to_csv("datos/X_test.csv", index=False)
